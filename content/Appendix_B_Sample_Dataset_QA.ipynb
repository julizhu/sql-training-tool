# %% [markdown]
# ## DATA VALIDATION
#
# This notebook loads all of the data sets used in this SQL tool and quickly QAs them to make sure the level of data dirtiness is as expected. Any unexpected irregularities should be noted and fixed accordingly.

# %%
# %load_ext sql
# %sql postgresql://localhost/postgres
# %config SqlMagic.displaylimit=10
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ### TABLE OF CONTENTS
# 1. [ACTOR](#ACTOR)
# 2. [FILM_ACTOR](#FILM_ACTOR)
# 3. [RENTAL](#RENTAL)
# 4. [FILM](#FILM)
# 5. [LANGUAGE](#LANGUAGE)
# 6. [FILM_CATEGORY](#FILM_CATEGORY)
# 7. [CATEGORY](#CATEGORY)

# %% [markdown]
# ### ACTOR
# * Looks at overall data schema and performs basic distinct counts
# * Update dates can be all the same time or different (assume that actors are manually maintained by an intern heh)
# * Expect dirty data (duplicate actors in the system)

# %%
# %%sql
# select * from actor
# Out:
#  * postgresql://localhost/postgres
# 200 rows affected.
# [(1, 'Penelope', 'Guiness', datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 'Nick', 'Wahlberg', datetime.datetime(2006, 2, 15, 10, 5)),
#  (3, 'Ed', 'Chase', datetime.datetime(2006, 2, 15, 10, 5)),
#  (4, 'Jennifer', 'Davis', datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 'Johnny', 'Lollobrigida', datetime.datetime(2006, 2, 15, 10, 5)),
#  (6, 'Bette', 'Nicholson', datetime.datetime(2006, 2, 15, 10, 5)),
#  (7, 'Grace', 'Mostel', datetime.datetime(2006, 2, 15, 10, 5)),
#  (8, 'Matthew', 'Johansson', datetime.datetime(2006, 2, 15, 10, 5)),
#  (9, 'Joe', 'Swank', datetime.datetime(2006, 2, 15, 10, 5)),
#  (10, 'Christian', 'Gable', datetime.datetime(2006, 2, 15, 10, 5)),
#  (11, 'Zero', 'Cage', datetime.datetime(2006, 2, 15, 10, 5)),
#  (12, 'Karl', 'Berry', datetime.datetime(2006, 2, 15, 10, 5)),
#  (13, 'Uma', 'Wood', datetime.datetime(2006, 2, 15, 10, 5)),
#  (14, 'Vivien', 'Bergen', datetime.datetime(2006, 2, 15, 10, 5)),
#  (15, 'Cuba', 'Olivier', datetime.datetime(2006, 2, 15, 10, 5)),
#  (16, 'Fred', 'Costner', datetime.datetime(2006, 2, 15, 10, 5)),
#  (17, 'Helen', 'Voight', datetime.datetime(2006, 2, 15, 10, 5)),
#  (18, 'Dan', 'Torn', datetime.datetime(2006, 2, 15, 10, 5)),
#  (19, 'Bob', 'Fawcett', datetime.datetime(2006, 2, 15, 10, 5)),
#  (20, 'Lucille', 'Tracy', datetime.datetime(2006, 2, 15, 10, 5)),
#  (21, 'Kirsten', 'Paltrow', datetime.datetime(2006, 2, 15, 10, 5)),
#  (22, 'Elvis', 'Marx', datetime.datetime(2006, 2, 15, 10, 5)),
#  (23, 'Sandra', 'Kilmer', datetime.datetime(2006, 2, 15, 10, 5)),
#  (24, 'Cameron', 'Streep', datetime.datetime(2006, 2, 15, 10, 5)),
#  (25, 'Kevin', 'Bloom', datetime.datetime(2006, 2, 15, 10, 5)),
#  (26, 'Rip', 'Crawford', datetime.datetime(2006, 2, 15, 10, 5)),
#  (27, 'Julia', 'Mcqueen', datetime.datetime(2006, 2, 15, 10, 5)),
#  (28, 'Woody', 'Hoffman', datetime.datetime(2006, 2, 15, 10, 5)),
#  (29, 'Alec', 'Wayne', datetime.datetime(2006, 2, 15, 10, 5)),
#  (30, 'Sandra', 'Peck', datetime.datetime(2006, 2, 15, 10, 5)),
#  (31, 'Sissy', 'Sobieski', datetime.datetime(2006, 2, 15, 10, 5)),
#  (32, 'Tim', 'Hackman', datetime.datetime(2006, 2, 15, 10, 5)),
#  (33, 'Milla', 'Peck', datetime.datetime(2006, 2, 15, 10, 5)),
#  (34, 'Audrey', 'Olivier', datetime.datetime(2006, 2, 15, 10, 5)),
#  (35, 'Judy', 'Dean', datetime.datetime(2006, 2, 15, 10, 5)),
#  (36, 'Burt', 'Dukakis', datetime.datetime(2006, 2, 15, 10, 5)),
#  (37, 'Val', 'Bolger', datetime.datetime(2006, 2, 15, 10, 5)),
#  (38, 'Tom', 'Mckellen', datetime.datetime(2006, 2, 15, 10, 5)),
#  (39, 'Goldie', 'Brody', datetime.datetime(2006, 2, 15, 10, 5)),
#  (40, 'Johnny', 'Cage', datetime.datetime(2006, 2, 15, 10, 5)),
#  (41, 'Jodie', 'Degeneres', datetime.datetime(2006, 2, 15, 10, 5)),
#  (42, 'Tom', 'Miranda', datetime.datetime(2006, 2, 15, 10, 5)),
#  (43, 'Kirk', 'Jovovich', datetime.datetime(2006, 2, 15, 10, 5)),
#  (44, 'Nick', 'Stallone', datetime.datetime(2006, 2, 15, 10, 5)),
#  (45, 'Reese', 'Kilmer', datetime.datetime(2006, 2, 15, 10, 5)),
#  (46, 'Parker', 'Goldberg', datetime.datetime(2006, 2, 15, 10, 5)),
#  (47, 'Julia', 'Barrymore', datetime.datetime(2006, 2, 15, 10, 5)),
#  (48, 'Frances', 'Day-Lewis', datetime.datetime(2006, 2, 15, 10, 5)),
#  (49, 'Anne', 'Cronyn', datetime.datetime(2006, 2, 15, 10, 5)),
#  (50, 'Natalie', 'Hopkins', datetime.datetime(2006, 2, 15, 10, 5)),
#  (51, 'Gary', 'Phoenix', datetime.datetime(2006, 2, 15, 10, 5)),
#  (52, 'Carmen', 'Hunt', datetime.datetime(2006, 2, 15, 10, 5)),
#  (53, 'Mena', 'Temple', datetime.datetime(2006, 2, 15, 10, 5)),
#  (54, 'Penelope', 'Pinkett', datetime.datetime(2006, 2, 15, 10, 5)),
#  (55, 'Fay', 'Kilmer', datetime.datetime(2006, 2, 15, 10, 5)),
#  (56, 'Dan', 'Harris', datetime.datetime(2006, 2, 15, 10, 5)),
#  (57, 'Jude', 'Cruise', datetime.datetime(2006, 2, 15, 10, 5)),
#  (58, 'Christian', 'Akroyd', datetime.datetime(2006, 2, 15, 10, 5)),
#  (59, 'Dustin', 'Tautou', datetime.datetime(2006, 2, 15, 10, 5)),
#  (60, 'Henry', 'Berry', datetime.datetime(2006, 2, 15, 10, 5)),
#  (61, 'Christian', 'Neeson', datetime.datetime(2006, 2, 15, 10, 5)),
#  (62, 'Jayne', 'Neeson', datetime.datetime(2006, 2, 15, 10, 5)),
#  (63, 'Cameron', 'Wray', datetime.datetime(2006, 2, 15, 10, 5)),
#  (64, 'Ray', 'Johansson', datetime.datetime(2006, 2, 15, 10, 5)),
#  (65, 'Angela', 'Hudson', datetime.datetime(2006, 2, 15, 10, 5)),
#  (66, 'Mary', 'Tandy', datetime.datetime(2006, 2, 15, 10, 5)),
#  (67, 'Jessica', 'Bailey', datetime.datetime(2006, 2, 15, 10, 5)),
#  (68, 'Rip', 'Winslet', datetime.datetime(2006, 2, 15, 10, 5)),
#  (69, 'Kenneth', 'Paltrow', datetime.datetime(2006, 2, 15, 10, 5)),
#  (70, 'Michelle', 'Mcconaughey', datetime.datetime(2006, 2, 15, 10, 5)),
#  (71, 'Adam', 'Grant', datetime.datetime(2006, 2, 15, 10, 5)),
#  (72, 'Sean', 'Williams', datetime.datetime(2006, 2, 15, 10, 5)),
#  (73, 'Gary', 'Penn', datetime.datetime(2006, 2, 15, 10, 5)),
#  (74, 'Milla', 'Keitel', datetime.datetime(2006, 2, 15, 10, 5)),
#  (75, 'Burt', 'Posey', datetime.datetime(2006, 2, 15, 10, 5)),
#  (76, 'Angelina', 'Astaire', datetime.datetime(2006, 2, 15, 10, 5)),
#  (77, 'Cary', 'Mcconaughey', datetime.datetime(2006, 2, 15, 10, 5)),
#  (78, 'Groucho', 'Sinatra', datetime.datetime(2006, 2, 15, 10, 5)),
#  (79, 'Mae', 'Hoffman', datetime.datetime(2006, 2, 15, 10, 5)),
#  (80, 'Ralph', 'Cruz', datetime.datetime(2006, 2, 15, 10, 5)),
#  (81, 'Scarlett', 'Damon', datetime.datetime(2006, 2, 15, 10, 5)),
#  (82, 'Woody', 'Jolie', datetime.datetime(2006, 2, 15, 10, 5)),
#  (83, 'Ben', 'Willis', datetime.datetime(2006, 2, 15, 10, 5)),
#  (84, 'James', 'Pitt', datetime.datetime(2006, 2, 15, 10, 5)),
#  (85, 'Minnie', 'Zellweger', datetime.datetime(2006, 2, 15, 10, 5)),
#  (143, 'River', 'Dean', datetime.datetime(2006, 2, 15, 10, 5)),
#  (86, 'Greg', 'Chaplin', datetime.datetime(2006, 2, 15, 10, 5)),
#  (87, 'Spencer', 'Peck', datetime.datetime(2006, 2, 15, 10, 5)),
#  (88, 'Kenneth', 'Pesci', datetime.datetime(2006, 2, 15, 10, 5)),
#  (89, 'Charlize', 'Dench', datetime.datetime(2006, 2, 15, 10, 5)),
#  (90, 'Sean', 'Guiness', datetime.datetime(2006, 2, 15, 10, 5)),
#  (91, 'Christopher', 'Berry', datetime.datetime(2006, 2, 15, 10, 5)),
#  (92, 'Kirsten', 'Akroyd', datetime.datetime(2006, 2, 15, 10, 5)),
#  (93, 'Ellen', 'Presley', datetime.datetime(2006, 2, 15, 10, 5)),
#  (94, 'Kenneth', 'Torn', datetime.datetime(2006, 2, 15, 10, 5)),
#  (95, 'Daryl', 'Wahlberg', datetime.datetime(2006, 2, 15, 10, 5)),
#  (96, 'Gene', 'Willis', datetime.datetime(2006, 2, 15, 10, 5)),
#  (97, 'Meg', 'Hawke', datetime.datetime(2006, 2, 15, 10, 5)),
#  (98, 'Chris', 'Bridges', datetime.datetime(2006, 2, 15, 10, 5)),
#  (99, 'Jim', 'Mostel', datetime.datetime(2006, 2, 15, 10, 5)),
#  (100, 'Spencer', 'Depp', datetime.datetime(2006, 2, 15, 10, 5)),
#  (101, 'Laura', 'VerHulst', datetime.datetime(2006, 2, 15, 10, 5)),
#  (102, 'Walter', 'Torn', datetime.datetime(2006, 2, 15, 10, 5)),
#  (103, 'Matthew', 'Leigh', datetime.datetime(2006, 2, 15, 10, 5)),
#  (104, 'Penelope', 'Cronyn', datetime.datetime(2006, 2, 15, 10, 5)),
#  (105, 'Sidney', 'Crowe', datetime.datetime(2006, 2, 15, 10, 5)),
#  (106, 'Groucho', 'Dunst', datetime.datetime(2006, 2, 15, 10, 5)),
#  (107, 'Gina', 'Degeneres', datetime.datetime(2006, 2, 15, 10, 5)),
#  (108, 'Warren', 'Nolte', datetime.datetime(2006, 2, 15, 10, 5)),
#  (109, 'Sylvester', 'Dern', datetime.datetime(2006, 2, 15, 10, 5)),
#  (110, 'Laura', 'VerHulst', datetime.datetime(2006, 2, 15, 10, 5)),
#  (111, 'Cameron', 'Zellweger', datetime.datetime(2006, 2, 15, 10, 5)),
#  (112, 'Russell', 'Bacall', datetime.datetime(2006, 2, 15, 10, 5)),
#  (113, 'Morgan', 'Hopkins', datetime.datetime(2006, 2, 15, 10, 5)),
#  (114, 'Morgan', 'Mcdormand', datetime.datetime(2006, 2, 15, 10, 5)),
#  (115, 'Harrison', 'Bale', datetime.datetime(2006, 2, 15, 10, 5)),
#  (116, 'Dan', 'Streep', datetime.datetime(2006, 2, 15, 10, 5)),
#  (117, 'Renee', 'Tracy', datetime.datetime(2006, 2, 15, 10, 5)),
#  (118, 'Cuba', 'Allen', datetime.datetime(2006, 2, 15, 10, 5)),
#  (119, 'Warren', 'Jackman', datetime.datetime(2006, 2, 15, 10, 5)),
#  (120, 'Penelope', 'Monroe', datetime.datetime(2006, 2, 15, 10, 5)),
#  (121, 'Liza', 'Bergman', datetime.datetime(2006, 2, 15, 10, 5)),
#  (122, 'Salma', 'Nolte', datetime.datetime(2006, 2, 15, 10, 5)),
#  (123, 'Julianne', 'Dench', datetime.datetime(2006, 2, 15, 10, 5)),
#  (124, 'Scarlett', 'Bening', datetime.datetime(2006, 2, 15, 10, 5)),
#  (125, 'Albert', 'Nolte', datetime.datetime(2006, 2, 15, 10, 5)),
#  (126, 'Frances', 'Tomei', datetime.datetime(2006, 2, 15, 10, 5)),
#  (127, 'Kevin', 'Garland', datetime.datetime(2006, 2, 15, 10, 5)),
#  (128, 'Cate', 'Mcqueen', datetime.datetime(2006, 2, 15, 10, 5)),
#  (129, 'Daryl', 'Crawford', datetime.datetime(2006, 2, 15, 10, 5)),
#  (130, 'Greta', 'Keitel', datetime.datetime(2006, 2, 15, 10, 5)),
#  (131, 'Jane', 'Jackman', datetime.datetime(2006, 2, 15, 10, 5)),
#  (132, 'Adam', 'Hopper', datetime.datetime(2006, 2, 15, 10, 5)),
#  (133, 'Richard', 'Penn', datetime.datetime(2006, 2, 15, 10, 5)),
#  (134, 'Gene', 'Hopkins', datetime.datetime(2006, 2, 15, 10, 5)),
#  (135, 'Rita', 'Reynolds', datetime.datetime(2006, 2, 15, 10, 5)),
#  (136, 'Ed', 'Mansfield', datetime.datetime(2006, 2, 15, 10, 5)),
#  (137, 'Morgan', 'Williams', datetime.datetime(2006, 2, 15, 10, 5)),
#  (138, 'Lucille', 'Dee', datetime.datetime(2006, 2, 15, 10, 5)),
#  (139, 'Ewan', 'Gooding', datetime.datetime(2006, 2, 15, 10, 5)),
#  (140, 'Whoopi', 'Hurt', datetime.datetime(2006, 2, 15, 10, 5)),
#  (141, 'Cate', 'Harris', datetime.datetime(2006, 2, 15, 10, 5)),
#  (142, 'Jada', 'Ryder', datetime.datetime(2006, 2, 15, 10, 5)),
#  (144, 'Angela', 'Witherspoon', datetime.datetime(2006, 2, 15, 10, 5)),
#  (145, 'Kim', 'Allen', datetime.datetime(2006, 2, 15, 10, 5)),
#  (146, 'Albert', 'Johansson', datetime.datetime(2006, 2, 15, 10, 5)),
#  (147, 'Fay', 'Winslet', datetime.datetime(2006, 2, 15, 10, 5)),
#  (148, 'Emily', 'Dee', datetime.datetime(2006, 2, 15, 10, 5)),
#  (149, 'Russell', 'Temple', datetime.datetime(2006, 2, 15, 10, 5)),
#  (150, 'Jayne', 'Nolte', datetime.datetime(2006, 2, 15, 10, 5)),
#  (151, 'Geoffrey', 'Heston', datetime.datetime(2006, 2, 15, 10, 5)),
#  (152, 'Ben', 'Harris', datetime.datetime(2006, 2, 15, 10, 5)),
#  (153, 'Minnie', 'Kilmer', datetime.datetime(2006, 2, 15, 10, 5)),
#  (154, 'Meryl', 'Gibson', datetime.datetime(2006, 2, 15, 10, 5)),
#  (155, 'Ian', 'Tandy', datetime.datetime(2006, 2, 15, 10, 5)),
#  (156, 'Fay', 'Wood', datetime.datetime(2006, 2, 15, 10, 5)),
#  (157, 'Greta', 'Malden', datetime.datetime(2006, 2, 15, 10, 5)),
#  (158, 'Vivien', 'Basinger', datetime.datetime(2006, 2, 15, 10, 5)),
#  (159, 'Laura', 'Brody', datetime.datetime(2006, 2, 15, 10, 5)),
#  (160, 'Chris', 'Depp', datetime.datetime(2006, 2, 15, 10, 5)),
#  (161, 'Harvey', 'Hope', datetime.datetime(2006, 2, 15, 10, 5)),
#  (162, 'Oprah', 'Kilmer', datetime.datetime(2006, 2, 15, 10, 5)),
#  (163, 'Christopher', 'West', datetime.datetime(2006, 2, 15, 10, 5)),
#  (164, 'Humphrey', 'Willis', datetime.datetime(2006, 2, 15, 10, 5)),
#  (165, 'Al', 'Garland', datetime.datetime(2006, 2, 15, 10, 5)),
#  (166, 'Nick', 'Degeneres', datetime.datetime(2006, 2, 15, 10, 5)),
#  (167, 'Laurence', 'Bullock', datetime.datetime(2006, 2, 15, 10, 5)),
#  (168, 'Will', 'Wilson', datetime.datetime(2006, 2, 15, 10, 5)),
#  (169, 'Kenneth', 'Hoffman', datetime.datetime(2006, 2, 15, 10, 5)),
#  (170, 'Mena', 'Hopper', datetime.datetime(2006, 2, 15, 10, 5)),
#  (171, 'Olympia', 'Pfeiffer', datetime.datetime(2006, 2, 15, 10, 5)),
#  (172, 'Groucho', 'Williams', datetime.datetime(2006, 2, 15, 10, 5)),
#  (173, 'Alan', 'Dreyfuss', datetime.datetime(2006, 2, 15, 10, 5)),
#  (174, 'Michael', 'Bening', datetime.datetime(2006, 2, 15, 10, 5)),
#  (175, 'William', 'Hackman', datetime.datetime(2006, 2, 15, 10, 5)),
#  (176, 'Jon', 'Chase', datetime.datetime(2006, 2, 15, 10, 5)),
#  (177, 'Gene', 'Mckellen', datetime.datetime(2006, 2, 15, 10, 5)),
#  (178, 'Lisa', 'Monroe', datetime.datetime(2006, 2, 15, 10, 5)),
#  (179, 'Ed', 'Guiness', datetime.datetime(2006, 2, 15, 10, 5)),
#  (180, 'Jeff', 'Silverstone', datetime.datetime(2006, 2, 15, 10, 5)),
#  (181, 'Matthew', 'Carrey', datetime.datetime(2006, 2, 15, 10, 5)),
#  (182, 'Debbie', 'Akroyd', datetime.datetime(2006, 2, 15, 10, 5)),
#  (183, 'Russell', 'Close', datetime.datetime(2006, 2, 15, 10, 5)),
#  (184, 'Humphrey', 'Garland', datetime.datetime(2006, 2, 15, 10, 5)),
#  (185, 'Michael', 'Bolger', datetime.datetime(2006, 2, 15, 10, 5)),
#  (186, 'Julia', 'Zellweger', datetime.datetime(2006, 2, 15, 10, 5)),
#  (187, 'Renee', 'Ball', datetime.datetime(2006, 2, 15, 10, 5)),
#  (188, 'Rock', 'Dukakis', datetime.datetime(2006, 2, 15, 10, 5)),
#  (189, 'Cuba', 'Birch', datetime.datetime(2006, 2, 15, 10, 5)),
#  (190, 'Audrey', 'Bailey', datetime.datetime(2006, 2, 15, 10, 5)),
#  (191, 'Gregory', 'Gooding', datetime.datetime(2006, 2, 15, 10, 5)),
#  (192, 'John', 'Suvari', datetime.datetime(2006, 2, 15, 10, 5)),
#  (193, 'Burt', 'Temple', datetime.datetime(2006, 2, 15, 10, 5)),
#  (194, 'Meryl', 'Allen', datetime.datetime(2006, 2, 15, 10, 5)),
#  (195, 'Jayne', 'Silverstone', datetime.datetime(2006, 2, 15, 10, 5)),
#  (196, 'Bela', 'Walken', datetime.datetime(2006, 2, 15, 10, 5)),
#  (197, 'Reese', 'West', datetime.datetime(2006, 2, 15, 10, 5)),
#  (198, 'Mary', 'Keitel', datetime.datetime(2006, 2, 15, 10, 5)),
#  (199, 'Julia', 'Fawcett', datetime.datetime(2006, 2, 15, 10, 5)),
#  (200, 'Thora', 'Temple', datetime.datetime(2006, 2, 15, 10, 5))]

# %%
# %%sql
# select count(*) from actor
# Out:
#  * postgresql://localhost/postgres
# 1 rows affected.
# [(200,)]

# %%
# %%sql
# -- Would be good if we had more than one duplicate
# select sum(1) from (select distinct first_name, last_name from actor) unique_actors
# Out:
#  * postgresql://localhost/postgres
# 1 rows affected.
# [(199,)]

# %%
# %%sql
# select first_name, last_name from actor group by first_name, last_name having count(*) > 1
# Out:
#  * postgresql://localhost/postgres
# 1 rows affected.
# [('Laura', 'VerHulst')]

# %%
# %%sql
# -- Looks like the actor_ids are messed up!
# select * from actor where first_name = 'Laura' and last_name = 'VerHulst'
# Out:
#  * postgresql://localhost/postgres
# 2 rows affected.
# [(101, 'Laura', 'VerHulst', datetime.datetime(2006, 2, 15, 10, 5)),
#  (110, 'Laura', 'VerHulst', datetime.datetime(2006, 2, 15, 10, 5))]

# %% [markdown]
# ### FILM_ACTOR
# * Looks at overall data schema and performs basic distinct counts
# * Make sure that the film and mapping include our dirty actor

# %%
# %%sql
# select * from film_actor
# Out:
#  * postgresql://localhost/postgres
# 5462 rows affected.
# [(1, 1, datetime.datetime(2006, 2, 15, 10, 5)),
#  (1, 23, datetime.datetime(2006, 2, 15, 10, 5)),
#  (1, 25, datetime.datetime(2006, 2, 15, 10, 5)),
#  (1, 106, datetime.datetime(2006, 2, 15, 10, 5)),
#  (1, 140, datetime.datetime(2006, 2, 15, 10, 5)),
#  (1, 166, datetime.datetime(2006, 2, 15, 10, 5)),
#  (1, 277, datetime.datetime(2006, 2, 15, 10, 5)),
#  (1, 361, datetime.datetime(2006, 2, 15, 10, 5)),
#  (1, 438, datetime.datetime(2006, 2, 15, 10, 5)),
#  (1, 499, datetime.datetime(2006, 2, 15, 10, 5)),
#  (1, 506, datetime.datetime(2006, 2, 15, 10, 5)),
#  (1, 509, datetime.datetime(2006, 2, 15, 10, 5)),
#  (1, 605, datetime.datetime(2006, 2, 15, 10, 5)),
#  (1, 635, datetime.datetime(2006, 2, 15, 10, 5)),
#  (1, 749, datetime.datetime(2006, 2, 15, 10, 5)),
#  (1, 832, datetime.datetime(2006, 2, 15, 10, 5)),
#  (1, 939, datetime.datetime(2006, 2, 15, 10, 5)),
#  (1, 970, datetime.datetime(2006, 2, 15, 10, 5)),
#  (1, 980, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 3, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 31, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 47, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 105, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 132, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 145, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 226, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 249, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 314, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 321, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 357, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 369, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 399, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 458, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 481, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 485, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 518, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 540, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 550, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 555, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 561, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 742, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 754, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 811, datetime.datetime(2006, 2, 15, 10, 5)),
#  (2, 958, datetime.datetime(2006, 2, 15, 10, 5)),
#  (3, 17, datetime.datetime(2006, 2, 15, 10, 5)),
#  (3, 40, datetime.datetime(2006, 2, 15, 10, 5)),
#  (3, 42, datetime.datetime(2006, 2, 15, 10, 5)),
#  (3, 87, datetime.datetime(2006, 2, 15, 10, 5)),
#  (3, 111, datetime.datetime(2006, 2, 15, 10, 5)),
#  (3, 185, datetime.datetime(2006, 2, 15, 10, 5)),
#  (3, 289, datetime.datetime(2006, 2, 15, 10, 5)),
#  (3, 329, datetime.datetime(2006, 2, 15, 10, 5)),
#  (3, 336, datetime.datetime(2006, 2, 15, 10, 5)),
#  (3, 341, datetime.datetime(2006, 2, 15, 10, 5)),
#  (3, 393, datetime.datetime(2006, 2, 15, 10, 5)),
#  (3, 441, datetime.datetime(2006, 2, 15, 10, 5)),
#  (3, 453, datetime.datetime(2006, 2, 15, 10, 5)),
#  (3, 480, datetime.datetime(2006, 2, 15, 10, 5)),
#  (3, 539, datetime.datetime(2006, 2, 15, 10, 5)),
#  (3, 618, datetime.datetime(2006, 2, 15, 10, 5)),
#  (3, 685, datetime.datetime(2006, 2, 15, 10, 5)),
#  (3, 827, datetime.datetime(2006, 2, 15, 10, 5)),
#  (3, 966, datetime.datetime(2006, 2, 15, 10, 5)),
#  (3, 967, datetime.datetime(2006, 2, 15, 10, 5)),
#  (3, 971, datetime.datetime(2006, 2, 15, 10, 5)),
#  (3, 996, datetime.datetime(2006, 2, 15, 10, 5)),
#  (4, 23, datetime.datetime(2006, 2, 15, 10, 5)),
#  (4, 25, datetime.datetime(2006, 2, 15, 10, 5)),
#  (4, 56, datetime.datetime(2006, 2, 15, 10, 5)),
#  (4, 62, datetime.datetime(2006, 2, 15, 10, 5)),
#  (4, 79, datetime.datetime(2006, 2, 15, 10, 5)),
#  (4, 87, datetime.datetime(2006, 2, 15, 10, 5)),
#  (4, 355, datetime.datetime(2006, 2, 15, 10, 5)),
#  (4, 379, datetime.datetime(2006, 2, 15, 10, 5)),
#  (4, 398, datetime.datetime(2006, 2, 15, 10, 5)),
#  (4, 463, datetime.datetime(2006, 2, 15, 10, 5)),
#  (4, 490, datetime.datetime(2006, 2, 15, 10, 5)),
#  (4, 616, datetime.datetime(2006, 2, 15, 10, 5)),
#  (4, 635, datetime.datetime(2006, 2, 15, 10, 5)),
#  (4, 691, datetime.datetime(2006, 2, 15, 10, 5)),
#  (4, 712, datetime.datetime(2006, 2, 15, 10, 5)),
#  (4, 714, datetime.datetime(2006, 2, 15, 10, 5)),
#  (4, 721, datetime.datetime(2006, 2, 15, 10, 5)),
#  (4, 798, datetime.datetime(2006, 2, 15, 10, 5)),
#  (4, 832, datetime.datetime(2006, 2, 15, 10, 5)),
#  (4, 858, datetime.datetime(2006, 2, 15, 10, 5)),
#  (4, 909, datetime.datetime(2006, 2, 15, 10, 5)),
#  (4, 924, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 19, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 54, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 85, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 146, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 171, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 172, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 202, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 203, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 286, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 288, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 316, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 340, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 369, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 375, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 383, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 392, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 411, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 503, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 535, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 571, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 650, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 665, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 687, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 730, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 732, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 811, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5, 817, datetime.datetime(2006, 2, 15, 10, 5)),
#  (5,
datetime.datetime(2006, 2, 15, 10, 5)),
#  (38, 853, datetime.datetime(2006, 2, 15, 10, 5)),
#  (38, 876, datetime.datetime(2006, 2, 15, 10, 5)),
#  (39, 71, datetime.datetime(2006, 2, 15, 10, 5)),
#  (39, 73, datetime.datetime(2006, 2, 15, 10, 5)),
#  (39, 168, datetime.datetime(2006, 2, 15, 10, 5)),
#  (39, 203, datetime.datetime(2006, 2, 15, 10, 5)),
#  (39, 222, datetime.datetime(2006, 2, 15, 10, 5)),
#  (39, 290, datetime.datetime(2006, 2, 15, 10, 5)),
#  (39, 293, datetime.datetime(2006, 2, 15, 10, 5)),
#  ...]

# %%
# %%sql
# select
#   column_name,
#   data_type
# from
#   information_schema.columns
# where
#   table_name = 'film_actor';
# Out:
#  * postgresql://localhost/postgres
# 3 rows affected.
# [('actor_id', 'integer'),
#  ('film_id', 'integer'),
#  ('last_update', 'timestamp without time zone')]

# %%
# %%sql
# select sum(1) from film_actor
# Out:
#  * postgresql://localhost/postgres
# 1 rows affected.
# [(5462,)]

# %%
# %%sql
# select count(distinct film_id) from film_actor
# Out:
#  * postgresql://localhost/postgres
# 1 rows affected.
# [(997,)]

# %%
# %%sql
# select count(distinct actor_id) from film_actor
# Out:
#  * postgresql://localhost/postgres
# 1 rows affected.
# [(200,)]

# %%
# %%sql
# select sum(1) from (select actor_id, film_id from film_actor group by actor_id, film_id) actor_pairs
# Out:
#  * postgresql://localhost/postgres
# 1 rows affected.
# [(5462,)]

# %%
# %%sql
# select actor_id, film_id from film_actor group by actor_id, film_id having count(*) > 1
# Out:
#  * postgresql://localhost/postgres
# 0 rows affected.
# []

# %%
# %%sql
# select * from film_actor where actor_id in (110, 101) limit 10
# Out:
#  * postgresql://localhost/postgres
# 10 rows affected.
# [(101, 60, datetime.datetime(2006, 2, 15, 10, 5)),
#  (101, 66, datetime.datetime(2006, 2, 15, 10, 5)),
#  (101, 85, datetime.datetime(2006, 2, 15, 10, 5)),
#  (101, 146, datetime.datetime(2006, 2, 15, 10, 5)),
#  (101, 189, datetime.datetime(2006, 2, 15, 10, 5)),
#  (101, 250, datetime.datetime(2006, 2, 15, 10, 5)),
#  (101, 255, datetime.datetime(2006, 2, 15, 10, 5)),
#  (101, 263, datetime.datetime(2006, 2, 15, 10, 5)),
#  (101, 275, datetime.datetime(2006, 2, 15, 10, 5)),
#  (101, 289, datetime.datetime(2006, 2, 15, 10, 5))]

# %%
# %%sql
# select
#   min(num_actors) as min_num_actors,
#   avg(num_actors) as avg_num_actors,
#   max(num_actors) as max_num_actors
# from
#   (select film_id, count(distinct actor_id) as num_actors from film_actor group by film_id) actor_count
# Out:
#  * postgresql://localhost/postgres
# 1 rows affected.
# [(1, Decimal('5.4784353059177533'), 15)]

# %% [markdown]
# ### RENTAL
# * Describes the rental activity of each DVD we have
# * last_update field can be the same because we have the intern
# * Looking for dirty data where return_date < rental_date

# %%
# %%sql
# select * from rental
# Out:
#  * postgresql://localhost/postgres
# 16044 rows affected.
# [(1, datetime.datetime(2005, 5, 24, 22, 53), 367, 130, datetime.datetime(2005, 5, 26, 22, 4), 1, datetime.datetime(2006, 2, 15, 21, 30)),
#  (2, datetime.datetime(2005, 5, 24, 22, 54), 1525, 459, datetime.datetime(2005, 5, 28, 19, 40), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (3, datetime.datetime(2005, 5, 24, 23, 3), 1711, 408, datetime.datetime(2005, 6, 1, 22, 12), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (4, datetime.datetime(2005, 5, 24, 23, 4), 2452, 333, datetime.datetime(2005, 6, 3, 1, 43), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (5, datetime.datetime(2005, 5, 24, 23, 5), 2079, 222, datetime.datetime(2005, 6, 2, 4, 33), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (6, datetime.datetime(2005, 5, 24, 23, 8), 2792, 549, datetime.datetime(2005, 5, 27, 1, 32), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (7, datetime.datetime(2005, 5, 24, 23, 11), 3995, 269, datetime.datetime(2005, 5, 29, 20, 34), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (8, datetime.datetime(2005, 5, 24, 23, 31), 2346, 239, datetime.datetime(2005, 5, 27, 23, 33), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (9, datetime.datetime(2005, 5, 25, 0, 0), 2580, 126, datetime.datetime(2005, 5, 28, 0, 22), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (10, datetime.datetime(2005, 5, 25, 0, 2), 1824, 399, datetime.datetime(2005, 5, 31, 22, 44), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (11, datetime.datetime(2005, 5, 25, 0, 9), 4443, 142, datetime.datetime(2005, 6, 2, 20, 56), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (12, datetime.datetime(2005, 5, 25, 0, 19), 1584, 261, datetime.datetime(2005, 5, 30, 5, 44), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (13, datetime.datetime(2005, 5, 25, 0, 22), 2294, 334, datetime.datetime(2005, 5, 30, 4, 28), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (14, datetime.datetime(2005, 5, 25, 0, 31), 2701, 446, datetime.datetime(2005, 5, 26, 2, 56), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (15, datetime.datetime(2005, 5, 25, 0, 39), 3049, 319, datetime.datetime(2005, 6, 3, 3, 30), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (16, datetime.datetime(2005, 5, 25, 0, 43), 389, 316, datetime.datetime(2005, 5, 26, 4, 42), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (17, datetime.datetime(2005, 5, 25, 1, 6), 830, 575, datetime.datetime(2005, 5, 27, 0, 43), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (18, datetime.datetime(2005, 5, 25, 1, 10), 3376, 19, datetime.datetime(2005, 5, 31, 6, 35), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (19, datetime.datetime(2005, 5, 25, 1, 17), 1941, 456, datetime.datetime(2005, 5, 31, 6, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (20, datetime.datetime(2005, 5, 25, 1, 48), 3517, 185, datetime.datetime(2005, 5, 27, 2, 20), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (21, datetime.datetime(2005, 5, 25, 1, 59), 146, 388, datetime.datetime(2005, 5, 26, 1, 1), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (22, datetime.datetime(2005, 5, 25, 2, 19), 727, 509, datetime.datetime(2005, 5, 26, 4, 52), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (23, datetime.datetime(2005, 5, 25, 2, 40), 4441, 438, datetime.datetime(2005, 5, 29, 6, 34), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (24, datetime.datetime(2005, 5, 25, 2, 53), 3273, 350, datetime.datetime(2005, 5, 27, 1, 15), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (25, datetime.datetime(2005, 5, 25, 3, 21), 3961, 37, datetime.datetime(2005, 5, 27, 21, 25), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (26, datetime.datetime(2005, 5, 25, 3, 36), 4371, 371, datetime.datetime(2005, 5, 31, 0, 34), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (27, datetime.datetime(2005, 5, 25, 3, 41), 1225, 301, datetime.datetime(2005, 5, 30, 1, 13), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (28, datetime.datetime(2005, 5, 25, 3, 42), 4068, 232, datetime.datetime(2005, 5, 26, 9, 26), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (29, datetime.datetime(2005, 5, 25, 3, 47), 611, 44, datetime.datetime(2005, 5, 30, 0, 31), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (30, datetime.datetime(2005, 5, 25, 4, 1), 3744, 430, datetime.datetime(2005, 5, 30, 3, 12), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (31, datetime.datetime(2005, 5, 25, 4, 5), 4482, 369, datetime.datetime(2005, 5, 30, 7, 15), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (32, datetime.datetime(2005, 5, 25, 4, 6), 3832, 230, datetime.datetime(2005, 5, 25, 23, 55), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (33, datetime.datetime(2005, 5, 25, 4, 18), 1681, 272, datetime.datetime(2005, 5, 27, 3, 58), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (34, datetime.datetime(2005, 5, 25, 4, 19), 2613, 597, datetime.datetime(2005, 5, 29, 0, 10), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (35, datetime.datetime(2005, 5, 25, 4, 24), 1286, 484, datetime.datetime(2005, 5, 27, 7, 2), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (36, datetime.datetime(2005, 5, 25, 4, 36), 1308, 88, datetime.datetime(2005, 5, 29, 0, 31), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (37, datetime.datetime(2005, 5, 25, 4, 44), 403, 535, datetime.datetime(2005, 5, 29, 1, 3), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (38, datetime.datetime(2005, 5, 25, 4, 47), 2540, 302, datetime.datetime(2005, 6, 1, 0, 58), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (39, datetime.datetime(2005, 5, 25, 4, 51), 4466, 207, datetime.datetime(2005, 5, 31, 3, 14), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (40, datetime.datetime(2005, 5, 25, 5, 9), 2638, 413, datetime.datetime(2005, 5, 27, 23, 12), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (41, datetime.datetime(2005, 5, 25, 5, 12), 1761, 174, datetime.datetime(2005, 6, 2, 0, 28), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (42, datetime.datetime(2005, 5, 25, 5, 24), 380, 523, datetime.datetime(2005, 5, 31, 2, 47), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (43, datetime.datetime(2005, 5, 25, 5, 39), 2578, 532, datetime.datetime(2005, 5, 26, 6, 54), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (44, datetime.datetime(2005, 5, 25, 5, 53), 3098, 207, datetime.datetime(2005, 5, 29, 10, 56), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (45, datetime.datetime(2005, 5, 25, 5, 59), 1853, 436, datetime.datetime(2005, 6, 2, 9, 56), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (46, datetime.datetime(2005, 5, 25, 6, 4), 3318, 7, datetime.datetime(2005, 6, 2, 8, 18), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (47, datetime.datetime(2005, 5, 25, 6, 5), 2211, 35, datetime.datetime(2005, 5, 30, 3, 4), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (48, datetime.datetime(2005, 5, 25, 6, 20), 1780, 282, datetime.datetime(2005, 6, 2, 5, 42), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (49, datetime.datetime(2005, 5, 25, 6, 39), 2965, 498, datetime.datetime(2005, 5, 30, 10, 12), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (50, datetime.datetime(2005, 5, 25, 6, 44), 1983, 18, datetime.datetime(2005, 5, 28, 11, 28), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (51, datetime.datetime(2005, 5, 25, 6, 49), 1257, 256, datetime.datetime(2005, 5, 26, 6, 42), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (52, datetime.datetime(2005, 5, 25, 6, 51), 4017, 507, datetime.datetime(2005, 5, 31, 1, 27), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (53, datetime.datetime(2005, 5, 25, 7, 19), 1255, 569, datetime.datetime(2005, 5, 27, 5, 19), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (54, datetime.datetime(2005, 5, 25, 7, 23), 2787, 291, datetime.datetime(2005, 6, 1, 5, 5), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (55, datetime.datetime(2005, 5, 25, 8, 26), 1139, 131, datetime.datetime(2005, 5, 30, 10, 57), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (56, datetime.datetime(2005, 5, 25, 8, 28), 1352, 511, datetime.datetime(2005, 5, 26, 14, 21), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (57, datetime.datetime(2005, 5, 25, 8, 43), 3938, 6, datetime.datetime(2005, 5, 29, 6, 42), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (58, datetime.datetime(2005, 5, 25, 8, 53), 3050, 323, datetime.datetime(2005, 5, 28, 14, 40), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (59, datetime.datetime(2005, 5, 25, 8, 56), 2884, 408, datetime.datetime(2005, 6, 1, 9, 52), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (60, datetime.datetime(2005, 5, 25, 8, 58), 330, 470, datetime.datetime(2005, 5, 30, 14, 14), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (61, datetime.datetime(2005, 5, 25, 9, 1), 4210, 250, datetime.datetime(2005, 6, 2, 7, 22), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (62, datetime.datetime(2005, 5, 25, 9, 18), 261, 419, datetime.datetime(2005, 5, 30, 10, 55), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (63, datetime.datetime(2005, 5, 25, 9, 19), 4008, 383, datetime.datetime(2005, 5, 27, 4, 24), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (64, datetime.datetime(2005, 5, 25, 9, 21), 79, 368, datetime.datetime(2005, 6, 3, 11, 31), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (65, datetime.datetime(2005, 5, 25, 9, 32), 3552, 346, datetime.datetime(2005, 5, 29, 14, 21), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (66, datetime.datetime(2005, 5, 25, 9, 35), 1162, 86, datetime.datetime(2005, 5, 29, 4, 16), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (67, datetime.datetime(2005, 5, 25, 9, 41), 239, 119, datetime.datetime(2005, 5, 27, 13, 46), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (68, datetime.datetime(2005, 5, 25, 9, 47), 4029, 120, datetime.datetime(2005, 5, 31, 10, 20), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (69, datetime.datetime(2005, 5, 25, 10, 10), 3207, 305, datetime.datetime(2005, 5, 27, 14, 2), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (70, datetime.datetime(2005, 5, 25, 10, 15), 2168, 73, datetime.datetime(2005, 5, 27, 5, 56), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (71, datetime.datetime(2005, 5, 25, 10, 26), 2408, 100, datetime.datetime(2005, 5, 28, 4, 59), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (72, datetime.datetime(2005, 5, 25, 10, 52), 2260, 48, datetime.datetime(2005, 5, 28, 5, 52), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (73, datetime.datetime(2005, 5, 25, 11, 0), 517, 391, datetime.datetime(2005, 6, 1, 13, 56), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (74, datetime.datetime(2005, 5, 25, 11, 9), 1744, 265, datetime.datetime(2005, 5, 26, 12, 23), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (75, datetime.datetime(2005, 5, 25, 11, 13), 3393, 510, datetime.datetime(2005, 6, 3, 12, 58), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (76, datetime.datetime(2005, 5, 25, 11, 30), 3021, 1, datetime.datetime(2005, 6, 3, 12, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (77, datetime.datetime(2005, 5, 25, 11, 31), 1303, 451, datetime.datetime(2005, 5, 26, 16, 53), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (78, datetime.datetime(2005, 5, 25, 11, 35), 4067, 135, datetime.datetime(2005, 5, 31, 12, 48), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (79, datetime.datetime(2005, 5, 25, 12, 11), 3299, 245, datetime.datetime(2005, 6, 3, 10, 54), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (80, datetime.datetime(2005, 5, 25, 12, 12), 2478, 314, datetime.datetime(2005, 5, 31, 17, 46), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (81, datetime.datetime(2005, 5, 25, 12, 15), 2610, 286, datetime.datetime(2005, 6, 2, 14, 8), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (82, datetime.datetime(2005, 5, 25, 12, 17), 1388, 427, datetime.datetime(2005, 6, 1, 10, 48), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (83, datetime.datetime(2005, 5, 25, 12, 30), 466, 131, datetime.datetime(2005, 5, 27, 15, 40), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (84, datetime.datetime(2005, 5, 25, 12, 36), 1829, 492, datetime.datetime(2005, 5, 29, 18, 33), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (85, datetime.datetime(2005, 5, 25, 13, 5), 470, 414, datetime.datetime(2005, 5, 29, 16, 53), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (86, datetime.datetime(2005, 5, 25, 13, 36), 2275, 266, datetime.datetime(2005, 5, 30, 14, 53), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (87, datetime.datetime(2005, 5, 25, 13, 52), 1586, 331, datetime.datetime(2005, 5, 29, 11, 12), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (88, datetime.datetime(2005, 5, 25, 14, 13), 2221, 53, datetime.datetime(2005, 5, 29, 9, 32), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (89, datetime.datetime(2005, 5, 25, 14, 28), 2181, 499, datetime.datetime(2005, 5, 29, 14, 33), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (90, datetime.datetime(2005, 5, 25, 14, 31), 2984, 25, datetime.datetime(2005, 6, 1, 10, 7), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (91, datetime.datetime(2005, 5, 25, 14, 57), 139, 267, datetime.datetime(2005, 6, 1, 18, 32), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (92, datetime.datetime(2005, 5, 25, 15, 38), 775, 302, datetime.datetime(2005, 5, 31, 13, 40), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (93, datetime.datetime(2005, 5, 25, 15, 54), 4360, 288, datetime.datetime(2005, 6, 3, 20, 18), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (94, datetime.datetime(2005, 5, 25, 16, 3), 1675, 197, datetime.datetime(2005, 5, 30, 14, 23), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (95, datetime.datetime(2005, 5, 25, 16, 12), 178, 400, datetime.datetime(2005, 6, 2, 18, 55), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (96, datetime.datetime(2005, 5, 25, 16, 32), 3418, 49, datetime.datetime(2005, 5, 30, 10, 47), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (97, datetime.datetime(2005, 5, 25, 16, 34), 1283, 263, datetime.datetime(2005, 5, 28, 12, 13), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (98, datetime.datetime(2005, 5, 25, 16, 48), 2970, 269, datetime.datetime(2005, 5, 27, 11, 29), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (99, datetime.datetime(2005, 5, 25, 16, 50), 535, 44, datetime.datetime(2005, 5, 28, 18, 52), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (100, datetime.datetime(2005, 5, 25, 16, 50), 2599, 208, datetime.datetime(2005, 6, 2, 22, 11), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (101, datetime.datetime(2005, 5, 25, 17, 17), 617, 468, datetime.datetime(2005, 5, 31, 19, 47), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (102, datetime.datetime(2005, 5, 25, 17, 22), 373, 343, datetime.datetime(2005, 5, 31, 19, 47), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (103, datetime.datetime(2005, 5, 25, 17, 30), 3343, 384, datetime.datetime(2005, 6, 3, 22, 36), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (104, datetime.datetime(2005, 5, 25, 17, 46), 4281, 310, datetime.datetime(2005, 5, 27, 15, 20), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (105, datetime.datetime(2005, 5, 25, 17, 54), 794, 108, datetime.datetime(2005, 5, 30, 12, 3), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (106, datetime.datetime(2005, 5, 25, 18, 18), 3627, 196, datetime.datetime(2005, 6, 4, 0, 1), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (107, datetime.datetime(2005, 5, 25, 18, 28), 2833, 317, datetime.datetime(2005, 6, 3, 22, 46), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (108, datetime.datetime(2005, 5, 25, 18, 30), 3289, 242, datetime.datetime(2005, 5, 30, 19, 40), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (109, datetime.datetime(2005, 5, 25, 18, 40), 1044, 503, datetime.datetime(2005, 5, 29, 20, 39), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (110, datetime.datetime(2005, 5, 25, 18, 43), 4108, 19, datetime.datetime(2005, 6, 3, 18, 13), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (111, datetime.datetime(2005, 5, 25, 18, 45), 3725, 227, datetime.datetime(2005, 5, 28, 17, 18), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (112, datetime.datetime(2005, 5, 25, 18, 57), 2153, 500, datetime.datetime(2005, 6, 2, 20, 44), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (113, datetime.datetime(2005, 5, 25, 19, 7), 2963, 93, datetime.datetime(2005, 5, 27, 22, 16), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (114, datetime.datetime(2005, 5, 25, 19, 12), 4502, 506, datetime.datetime(2005, 6, 1, 23, 10), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (115, datetime.datetime(2005, 5, 25, 19, 13), 749, 455, datetime.datetime(2005, 5, 29, 20, 17), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (116, datetime.datetime(2005, 5, 25, 19, 27), 4453, 18, datetime.datetime(2005, 5, 26, 16, 23), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (117, datetime.datetime(2005, 5, 25, 19, 30), 4278, 7, datetime.datetime(2005, 5, 31, 23, 59), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (118, datetime.datetime(2005, 5, 25, 19, 31), 872, 524, datetime.datetime(2005, 5, 31, 15, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (119, datetime.datetime(2005, 5, 25, 19, 37), 1359, 51, datetime.datetime(2005, 5, 29, 23, 51), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (120, datetime.datetime(2005, 5, 25, 19, 37), 37, 365, datetime.datetime(2005, 6, 1, 23, 29), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (121, datetime.datetime(2005, 5, 25, 19, 41), 1053, 405, datetime.datetime(2005, 5, 29, 21, 31), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (122, datetime.datetime(2005, 5, 25, 19, 46), 2908, 273, datetime.datetime(2005, 6, 2, 19, 7), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (123, datetime.datetime(2005, 5, 25, 20, 26), 1795, 43, datetime.datetime(2005, 5, 26, 19, 41), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (124, datetime.datetime(2005, 5, 25, 20, 46), 212, 246, datetime.datetime(2005, 5, 30, 0, 47), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (125, datetime.datetime(2005, 5, 25, 20, 48), 952, 368, datetime.datetime(2005, 6, 2, 21, 39), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (126, datetime.datetime(2005, 5, 25, 21, 7), 2047, 439, datetime.datetime(2005, 5, 28, 18, 51), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (127, datetime.datetime(2005, 5, 25, 21, 10), 2026, 94, datetime.datetime(2005, 6, 2, 21, 38), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (128, datetime.datetime(2005, 5, 25, 21, 19), 4322, 40, datetime.datetime(2005, 5, 29, 23, 34), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (129, datetime.datetime(2005, 5, 25, 21, 20), 4154, 23, datetime.datetime(2005, 6, 4, 1, 25), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (130, datetime.datetime(2005, 5, 25, 21, 21), 3990, 56, datetime.datetime(2005, 5, 30, 22, 41), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (131, datetime.datetime(2005, 5, 25, 21, 42), 815, 325, datetime.datetime(2005, 5, 30, 23, 25), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (132, datetime.datetime(2005, 5, 25, 21, 46), 3367, 479, datetime.datetime(2005, 5, 31, 21, 2), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (133, datetime.datetime(2005, 5, 25, 21, 48), 399, 237, datetime.datetime(2005, 5, 30, 0, 26), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (134, datetime.datetime(2005, 5, 25, 21, 48), 2272, 222, datetime.datetime(2005, 6, 2, 18, 28), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (135, datetime.datetime(2005, 5, 25, 21, 58), 103, 304, datetime.datetime(2005, 6, 3, 17, 50), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (136, datetime.datetime(2005, 5, 25, 22, 2), 2296, 504, datetime.datetime(2005, 5, 31, 18, 6), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (137, datetime.datetime(2005, 5, 25, 22, 25), 2591, 560, datetime.datetime(2005, 6, 1, 2, 30), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (138, datetime.datetime(2005, 5, 25, 22, 48), 4134, 586, datetime.datetime(2005, 5, 29, 20, 21), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (139, datetime.datetime(2005, 5, 25, 23, 0), 327, 257, datetime.datetime(2005, 5, 29, 17, 12), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (140, datetime.datetime(2005, 5, 25, 23, 34), 655, 354, datetime.datetime(2005, 5, 27, 1, 10), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (141, datetime.datetime(2005, 5, 25, 23, 34), 811, 89, datetime.datetime(2005, 6, 2, 1, 57), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (142, datetime.datetime(2005, 5, 25, 23, 43), 4407, 472, datetime.datetime(2005, 5, 29, 0, 46), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (143, datetime.datetime(2005, 5, 25, 23, 45), 847, 297, datetime.datetime(2005, 5, 27, 21, 41), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (144, datetime.datetime(2005, 5, 25, 23, 49), 1689, 357, datetime.datetime(2005, 6, 1, 21, 41), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (145, datetime.datetime(2005, 5, 25, 23, 59), 3905, 82, datetime.datetime(2005, 5, 31, 2, 56), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (146, datetime.datetime(2005, 5, 26, 0, 7), 1431, 433, datetime.datetime(2005, 6, 4, 0, 20), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (147, datetime.datetime(2005, 5, 26, 0, 17), 633, 274, datetime.datetime(2005, 5, 29, 23, 21), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (148, datetime.datetime(2005, 5, 26, 0, 25), 4252, 142, datetime.datetime(2005, 6, 1, 19, 29), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (149, datetime.datetime(2005, 5, 26, 0, 28), 1084, 319, datetime.datetime(2005, 6, 2, 21, 30), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (150, datetime.datetime(2005, 5, 26, 0, 28), 909, 429, datetime.datetime(2005, 6, 1, 2, 10), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (151, datetime.datetime(2005, 5, 26, 0, 37), 2942, 14, datetime.datetime(2005, 5, 30, 6, 28), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (152, datetime.datetime(2005, 5, 26, 0, 41), 2622, 57, datetime.datetime(2005, 6, 3, 6, 5), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (153, datetime.datetime(2005, 5, 26, 0, 47), 3888, 348, datetime.datetime(2005, 5, 27, 21, 28), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (154, datetime.datetime(2005, 5, 26, 0, 55), 1354, 185, datetime.datetime(2005, 5, 29, 23, 18), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (155, datetime.datetime(2005, 5, 26, 1, 15), 288, 551, datetime.datetime(2005, 6, 1, 0, 3), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (156, datetime.datetime(2005, 5, 26, 1, 19), 3193, 462, datetime.datetime(2005, 5, 27, 23, 43), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (157, datetime.datetime(2005, 5, 26, 1, 25), 887, 344, datetime.datetime(2005, 5, 26, 21, 17), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (158, datetime.datetime(2005, 5, 26, 1, 27), 2395, 354, datetime.datetime(2005, 6, 3, 0, 30), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (159, datetime.datetime(2005, 5, 26, 1, 34), 3453, 505, datetime.datetime(2005, 5, 29, 4, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (160, datetime.datetime(2005, 5, 26, 1, 46), 1885, 290, datetime.datetime(2005, 6, 1, 5, 45), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (161, datetime.datetime(2005, 5, 26, 1, 51), 2941, 182, datetime.datetime(2005, 5, 27, 5, 42), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (162, datetime.datetime(2005, 5, 26, 2, 2), 1229, 296, datetime.datetime(2005, 5, 27, 3, 38), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (163, datetime.datetime(2005, 5, 26, 2, 26), 2306, 104, datetime.datetime(2005, 6, 4, 6, 36), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (164, datetime.datetime(2005, 5, 26, 2, 26), 1070, 151, datetime.datetime(2005, 5, 28, 0, 32), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (165, datetime.datetime(2005, 5, 26, 2, 28), 2735, 33, datetime.datetime(2005, 6, 2, 3, 21), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (166, datetime.datetime(2005, 5, 26, 2, 49), 3894, 322, datetime.datetime(2005, 5, 31, 1, 28), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (167, datetime.datetime(2005, 5, 26, 2, 50), 865, 401, datetime.datetime(2005, 5, 27, 3, 7), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (168, datetime.datetime(2005, 5, 26, 3, 7), 2714, 469, datetime.datetime(2005, 6, 2, 2, 9), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (169, datetime.datetime(2005, 5, 26, 3, 9), 1758, 381, datetime.datetime(2005, 5, 27, 1, 37), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (170, datetime.datetime(2005, 5, 26, 3, 11), 3688, 107, datetime.datetime(2005, 6, 2, 3, 53), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  
 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (280, datetime.datetime(2005, 5, 26, 18, 36), 1896, 167, datetime.datetime(2005, 5, 27, 23, 42), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (281, datetime.datetime(2005, 5, 26, 18, 49), 1208, 582, datetime.datetime(2005, 5, 27, 18, 11), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (282, datetime.datetime(2005, 5, 26, 18, 56), 4486, 282, datetime.datetime(2005, 6, 1, 16, 32), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (283, datetime.datetime(2005, 5, 26, 19, 5), 3530, 242, datetime.datetime(2005, 5, 31, 19, 19), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (284, datetime.datetime(2005, 5, 26, 19, 21), 350, 359, datetime.datetime(2005, 6, 4, 14, 18), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (285, datetime.datetime(2005, 5, 26, 19, 41), 2486, 162, datetime.datetime(2005, 5, 31, 16, 58), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (286, datetime.datetime(2005, 5, 26, 19, 44), 314, 371, datetime.datetime(2005, 6, 4, 18, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (287, datetime.datetime(2005, 5, 26, 19, 44), 3631, 17, datetime.datetime(2005, 6, 2, 1, 10), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (288, datetime.datetime(2005, 5, 26, 19, 47), 3546, 82, datetime.datetime(2005, 6, 3, 20, 53), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (289, datetime.datetime(2005, 5, 26, 20, 1), 2449, 81, datetime.datetime(2005, 5, 28, 15, 9), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (290, datetime.datetime(2005, 5, 26, 20, 8), 2776, 429, datetime.datetime(2005, 5, 30, 0, 32), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (291, datetime.datetime(2005, 5, 26, 20, 20), 485, 577, datetime.datetime(2005, 6, 3, 2, 6), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (292, datetime.datetime(2005, 5, 26, 20, 22), 4264, 515, datetime.datetime(2005, 6, 5, 0, 58), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (293, datetime.datetime(2005, 5, 26, 20, 27), 1828, 158, datetime.datetime(2005, 6, 3, 16, 45), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (294, datetime.datetime(2005, 5, 26, 20, 29), 2751, 369, datetime.datetime(2005, 5, 28, 17, 20), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (295, datetime.datetime(2005, 5, 26, 20, 33), 4030, 65, datetime.datetime(2005, 5, 27, 18, 23), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (296, datetime.datetime(2005, 5, 26, 20, 35), 3878, 468, datetime.datetime(2005, 6, 4, 2, 31), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (297, datetime.datetime(2005, 5, 26, 20, 48), 1594, 48, datetime.datetime(2005, 5, 27, 19, 52), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (298, datetime.datetime(2005, 5, 26, 20, 52), 1083, 460, datetime.datetime(2005, 5, 29, 22, 8), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (299, datetime.datetime(2005, 5, 26, 20, 55), 4376, 448, datetime.datetime(2005, 5, 28, 0, 25), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (300, datetime.datetime(2005, 5, 26, 20, 57), 249, 47, datetime.datetime(2005, 6, 5, 1, 34), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (301, datetime.datetime(2005, 5, 26, 21, 6), 3448, 274, datetime.datetime(2005, 6, 1, 1, 54), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (302, datetime.datetime(2005, 5, 26, 21, 13), 2921, 387, datetime.datetime(2005, 6, 3, 15, 49), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (303, datetime.datetime(2005, 5, 26, 21, 16), 1111, 596, datetime.datetime(2005, 5, 27, 23, 41), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (304, datetime.datetime(2005, 5, 26, 21, 21), 1701, 534, datetime.datetime(2005, 6, 2, 0, 5), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (305, datetime.datetime(2005, 5, 26, 21, 22), 2665, 464, datetime.datetime(2005, 6, 2, 22, 33), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (306, datetime.datetime(2005, 5, 26, 21, 31), 2781, 547, datetime.datetime(2005, 5, 28, 19, 37), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (307, datetime.datetime(2005, 5, 26, 21, 48), 1097, 375, datetime.datetime(2005, 6, 4, 22, 24), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (308, datetime.datetime(2005, 5, 26, 22, 1), 187, 277, datetime.datetime(2005, 6, 4, 20, 24), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (309, datetime.datetime(2005, 5, 26, 22, 38), 1946, 251, datetime.datetime(2005, 6, 2, 3, 10), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (310, datetime.datetime(2005, 5, 26, 22, 41), 593, 409, datetime.datetime(2005, 6, 2, 4, 9), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (311, datetime.datetime(2005, 5, 26, 22, 51), 2830, 201, datetime.datetime(2005, 6, 1, 0, 2), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (312, datetime.datetime(2005, 5, 26, 22, 52), 2008, 143, datetime.datetime(2005, 6, 2, 18, 14), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (313, datetime.datetime(2005, 5, 26, 22, 56), 4156, 594, datetime.datetime(2005, 5, 29, 1, 29), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (314, datetime.datetime(2005, 5, 26, 23, 9), 2851, 203, datetime.datetime(2005, 5, 28, 22, 49), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (315, datetime.datetime(2005, 5, 26, 23, 12), 2847, 238, datetime.datetime(2005, 5, 29, 23, 33), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (316, datetime.datetime(2005, 5, 26, 23, 22), 3828, 249, datetime.datetime(2005, 5, 29, 23, 25), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (317, datetime.datetime(2005, 5, 26, 23, 23), 26, 391, datetime.datetime(2005, 6, 1, 19, 56), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (318, datetime.datetime(2005, 5, 26, 23, 37), 2559, 60, datetime.datetime(2005, 6, 3, 4, 31), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (319, datetime.datetime(2005, 5, 26, 23, 52), 3024, 77, datetime.datetime(2005, 5, 30, 18, 55), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (320, datetime.datetime(2005, 5, 27, 0, 9), 1090, 2, datetime.datetime(2005, 5, 28, 4, 30), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (322, datetime.datetime(2005, 5, 27, 0, 47), 4556, 496, datetime.datetime(2005, 6, 2, 0, 32), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (323, datetime.datetime(2005, 5, 27, 0, 49), 2362, 144, datetime.datetime(2005, 5, 30, 3, 12), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (324, datetime.datetime(2005, 5, 27, 1, 0), 3364, 292, datetime.datetime(2005, 5, 30, 4, 27), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (325, datetime.datetime(2005, 5, 27, 1, 9), 2510, 449, datetime.datetime(2005, 5, 31, 7, 1), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (326, datetime.datetime(2005, 5, 27, 1, 10), 3979, 432, datetime.datetime(2005, 6, 4, 20, 25), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (327, datetime.datetime(2005, 5, 27, 1, 18), 2678, 105, datetime.datetime(2005, 6, 4, 4, 6), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (328, datetime.datetime(2005, 5, 27, 1, 29), 2524, 451, datetime.datetime(2005, 6, 1, 2, 27), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (329, datetime.datetime(2005, 5, 27, 1, 57), 2659, 231, datetime.datetime(2005, 5, 31, 4, 19), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (330, datetime.datetime(2005, 5, 27, 2, 15), 1536, 248, datetime.datetime(2005, 6, 4, 5, 9), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (331, datetime.datetime(2005, 5, 27, 2, 22), 1872, 67, datetime.datetime(2005, 6, 5, 0, 25), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (332, datetime.datetime(2005, 5, 27, 2, 27), 1529, 299, datetime.datetime(2005, 6, 3, 1, 26), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (333, datetime.datetime(2005, 5, 27, 2, 52), 4001, 412, datetime.datetime(2005, 6, 1, 0, 55), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (334, datetime.datetime(2005, 5, 27, 3, 3), 3973, 194, datetime.datetime(2005, 5, 29, 3, 54), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (335, datetime.datetime(2005, 5, 27, 3, 7), 1411, 16, datetime.datetime(2005, 6, 5, 0, 15), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (336, datetime.datetime(2005, 5, 27, 3, 15), 1811, 275, datetime.datetime(2005, 5, 29, 22, 43), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (337, datetime.datetime(2005, 5, 27, 3, 22), 751, 19, datetime.datetime(2005, 6, 2, 3, 27), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (338, datetime.datetime(2005, 5, 27, 3, 42), 2596, 165, datetime.datetime(2005, 6, 1, 5, 23), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (339, datetime.datetime(2005, 5, 27, 3, 47), 2410, 516, datetime.datetime(2005, 6, 4, 5, 46), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (340, datetime.datetime(2005, 5, 27, 3, 55), 946, 209, datetime.datetime(2005, 6, 4, 7, 57), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (341, datetime.datetime(2005, 5, 27, 4, 1), 4168, 56, datetime.datetime(2005, 6, 5, 8, 51), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (342, datetime.datetime(2005, 5, 27, 4, 11), 4019, 539, datetime.datetime(2005, 5, 29, 1, 28), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (343, datetime.datetime(2005, 5, 27, 4, 13), 3301, 455, datetime.datetime(2005, 5, 28, 8, 34), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (344, datetime.datetime(2005, 5, 27, 4, 30), 2327, 236, datetime.datetime(2005, 5, 29, 10, 13), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (345, datetime.datetime(2005, 5, 27, 4, 32), 1396, 144, datetime.datetime(2005, 5, 31, 9, 50), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (346, datetime.datetime(2005, 5, 27, 4, 34), 4319, 14, datetime.datetime(2005, 6, 5, 4, 24), 2, datetime.datetime(2006, 2, 16, 2, 30)),
# ...
#  (887, datetime.datetime(2005, 5, 30, 7, 10), 2727, 16, datetime.datetime(2005, 6, 1, 6, 48), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (888, datetime.datetime(2005, 5, 30, 7, 13), 387, 128, datetime.datetime(2005, 6, 6, 9, 50), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (889, datetime.datetime(2005, 5, 30, 7, 14), 1299, 114, datetime.datetime(2005, 5, 31, 7, 56), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (890, datetime.datetime(2005, 5, 30, 7, 43), 1464, 349, datetime.datetime(2005, 6, 1, 11, 26), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (891, datetime.datetime(2005, 5, 30, 7, 43), 2611, 391, datetime.datetime(2005, 6, 8, 9, 21), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (892, datetime.datetime(2005, 5, 30, 8, 2), 471, 274, datetime.datetime(2005, 6, 5, 12, 51), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (893, datetime.datetime(2005, 5, 30, 8, 6), 3260, 502, datetime.datetime(2005, 6, 7, 8, 23), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (894, datetime.datetime(2005, 5, 30, 8, 31), 1118, 400, datetime.datetime(2005, 6, 7, 12, 39), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (895, datetime.datetime(2005, 5, 30, 8, 50), 2744, 192, datetime.datetime(2005, 6, 5, 10, 58), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (896, datetime.datetime(2005, 5, 30, 9, 3), 2817, 207, datetime.datetime(2005, 6, 5, 7, 37), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (897, datetime.datetime(2005, 5, 30, 9, 10), 1334, 432, datetime.datetime(2005, 6, 8, 3, 43), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (898, datetime.datetime(2005, 5, 30, 9, 26), 3497, 384, datetime.datetime(2005, 6, 1, 10, 45), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (899, datetime.datetime(2005, 5, 30, 9, 29), 1096, 156, datetime.datetime(2005, 6, 6, 12, 39), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (900, datetime.datetime(2005, 5, 30, 9, 38), 3543, 586, datetime.datetime(2005, 6, 7, 11, 54), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (901, datetime.datetime(2005, 5, 30, 9, 40), 760, 259, datetime.datetime(2005, 6, 2, 10, 32), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (902, datetime.datetime(2005, 5, 30, 9, 53), 1514, 561, datetime.datetime(2005, 6, 7, 12, 10), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (903, datetime.datetime(2005, 5, 30, 10, 11), 2423, 197, datetime.datetime(2005, 6, 3, 9, 33), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (904, datetime.datetime(2005, 5, 30, 10, 19), 2466, 44, datetime.datetime(2005, 6, 5, 4, 58), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (905, datetime.datetime(2005, 5, 30, 10, 25), 4372, 50, datetime.datetime(2005, 6, 6, 6, 23), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (906, datetime.datetime(2005, 5, 30, 10, 30), 1862, 549, datetime.datetime(2005, 6, 7, 6, 44), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (907, datetime.datetime(2005, 5, 30, 10, 37), 3320, 506, datetime.datetime(2005, 6, 2, 9, 51), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (908, datetime.datetime(2005, 5, 30, 10, 38), 4427, 85, datetime.datetime(2005, 6, 3, 9, 56), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (909, datetime.datetime(2005, 5, 30, 10, 43), 3775, 486, datetime.datetime(2005, 6, 8, 12, 7), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (910, datetime.datetime(2005, 5, 30, 10, 46), 2601, 374, datetime.datetime(2005, 6, 4, 13, 32), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (911, datetime.datetime(2005, 5, 30, 10, 50), 1404, 366, datetime.datetime(2005, 6, 7, 12, 26), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (912, datetime.datetime(2005, 5, 30, 10, 58), 3200, 390, datetime.datetime(2005, 5, 31, 9, 31), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (913, datetime.datetime(2005, 5, 30, 11, 4), 3213, 369, datetime.datetime(2005, 6, 7, 13, 22), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (914, datetime.datetime(2005, 5, 30, 11, 6), 1393, 596, datetime.datetime(2005, 6, 4, 6, 7), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (915, datetime.datetime(2005, 5, 30, 11, 20), 1859, 115, datetime.datetime(2005, 6, 2, 11, 55), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (916, datetime.datetime(2005, 5, 30, 11, 25), 1290, 6, datetime.datetime(2005, 5, 31, 9, 6), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (917, datetime.datetime(2005, 5, 30, 11, 27), 3629, 385, datetime.datetime(2005, 6, 2, 8, 31), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (918, datetime.datetime(2005, 5, 30, 11, 32), 818, 197, datetime.datetime(2005, 5, 31, 7, 55), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (919, datetime.datetime(2005, 5, 30, 11, 35), 4052, 374, datetime.datetime(2005, 6, 2, 13, 16), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (920, datetime.datetime(2005, 5, 30, 11, 44), 3860, 584, datetime.datetime(2005, 6, 2, 8, 19), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (921, datetime.datetime(2005, 5, 30, 11, 53), 1827, 508, datetime.datetime(2005, 6, 3, 10, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (922, datetime.datetime(2005, 5, 30, 11, 55), 2442, 550, datetime.datetime(2005, 6, 8, 10, 12), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (923, datetime.datetime(2005, 5, 30, 11, 58), 1884, 37, datetime.datetime(2005, 6, 5, 9, 57), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (924, datetime.datetime(2005, 5, 30, 12, 10), 3279, 293, datetime.datetime(2005, 6, 4, 17, 28), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (925, datetime.datetime(2005, 5, 30, 12, 13), 3203, 137, datetime.datetime(2005, 6, 2, 14, 41), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (926, datetime.datetime(2005, 5, 30, 12, 15), 4327, 76, datetime.datetime(2005, 6, 1, 8, 53), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (927, datetime.datetime(2005, 5, 30, 12, 16), 1158, 167, datetime.datetime(2005, 5, 31, 16, 20), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (928, datetime.datetime(2005, 5, 30, 12, 27), 246, 79, datetime.datetime(2005, 6, 5, 13, 56), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (929, datetime.datetime(2005, 5, 30, 12, 32), 4296, 536, datetime.datetime(2005, 6, 6, 12, 17), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (930, datetime.datetime(2005, 5, 30, 12, 44), 2835, 141, datetime.datetime(2005, 6, 4, 10, 53), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (931, datetime.datetime(2005, 5, 30, 12, 53), 3384, 421, datetime.datetime(2005, 5, 31, 14, 28), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (932, datetime.datetime(2005, 5, 30, 12, 55), 719, 198, datetime.datetime(2005, 5, 31, 10, 30), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (933, datetime.datetime(2005, 5, 30, 13, 8), 3672, 66, datetime.datetime(2005, 6, 1, 18, 56), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (934, datetime.datetime(2005, 5, 30, 13, 24), 3595, 60, datetime.datetime(2005, 6, 8, 16, 44), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (935, datetime.datetime(2005, 5, 30, 13, 29), 2421, 256, datetime.datetime(2005, 6, 2, 11, 8), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (936, datetime.datetime(2005, 5, 30, 13, 52), 901, 469, datetime.datetime(2005, 6, 7, 16, 56), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (937, datetime.datetime(2005, 5, 30, 14, 47), 1054, 304, datetime.datetime(2005, 6, 5, 9, 53), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (938, datetime.datetime(2005, 5, 30, 14, 47), 1521, 46, datetime.datetime(2005, 6, 4, 10, 10), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (939, datetime.datetime(2005, 5, 30, 14, 49), 1314, 367, datetime.datetime(2005, 6, 1, 19, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (940, datetime.datetime(2005, 5, 30, 15, 1), 1278, 534, datetime.datetime(2005, 6, 1, 18, 26), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (941, datetime.datetime(2005, 5, 30, 15, 2), 3630, 562, datetime.datetime(2005, 6, 1, 17, 19), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (942, datetime.datetime(2005, 5, 30, 15, 5), 4279, 473, datetime.datetime(2005, 6, 8, 15, 59), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (943, datetime.datetime(2005, 5, 30, 15, 20), 3737, 57, datetime.datetime(2005, 6, 6, 18, 53), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (944, datetime.datetime(2005, 5, 30, 15, 26), 151, 131, datetime.datetime(2005, 6, 7, 18, 9), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (945, datetime.datetime(2005, 5, 30, 15, 33), 1441, 357, datetime.datetime(2005, 6, 2, 15, 2), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (946, datetime.datetime(2005, 5, 30, 15, 35), 1264, 486, datetime.datetime(2005, 6, 8, 11, 38), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (947, datetime.datetime(2005, 5, 30, 15, 36), 4478, 62, datetime.datetime(2005, 6, 4, 18, 48), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (948, datetime.datetime(2005, 5, 30, 15, 44), 585, 245, datetime.datetime(2005, 6, 8, 17, 30), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (949, datetime.datetime(2005, 5, 30, 15, 50), 2202, 368, datetime.datetime(2005, 6, 3, 14, 25), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (950, datetime.datetime(2005, 5, 30, 16, 6), 491, 83, datetime.datetime(2005, 6, 1, 11, 43), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (951, datetime.datetime(2005, 5, 30, 16, 10), 1395, 59, datetime.datetime(2005, 5, 31, 19, 1), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (952, datetime.datetime(2005, 5, 30, 16, 28), 4389, 311, datetime.datetime(2005, 6, 2, 16, 12), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (953, datetime.datetime(2005, 5, 30, 16, 34), 2194, 210, datetime.datetime(2005, 5, 31, 20, 34), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (954, datetime.datetime(2005, 5, 30, 16, 57), 1231, 297, datetime.datetime(2005, 6, 8, 13, 30), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (955, datetime.datetime(2005, 5, 30, 16, 59), 4140, 301, datetime.datetime(2005, 5, 31, 11, 58), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (956, datetime.datetime(2005, 5, 30, 17, 30), 647, 296, datetime.datetime(2005, 6, 7, 13, 54), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (957, datetime.datetime(2005, 5, 30, 17, 53), 4428, 440, datetime.datetime(2005, 6, 3, 15, 31), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (958, datetime.datetime(2005, 5, 30, 17, 58), 548, 186, datetime.datetime(2005, 6, 1, 19, 17), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (959, datetime.datetime(2005, 5, 30, 18, 7), 3108, 535, datetime.datetime(2005, 6, 2, 14, 37), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (960, datetime.datetime(2005, 5, 30, 18, 13), 1966, 445, datetime.datetime(2005, 6, 4, 0, 12), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (961, datetime.datetime(2005, 5, 30, 18, 16), 3293, 588, datetime.datetime(2005, 6, 4, 23, 40), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (962, datetime.datetime(2005, 5, 30, 18, 45), 4535, 520, datetime.datetime(2005, 6, 5, 22, 47), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (963, datetime.datetime(2005, 5, 30, 18, 52), 1921, 225, datetime.datetime(2005, 6, 7, 16, 19), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (964, datetime.datetime(2005, 5, 30, 18, 53), 657, 287, datetime.datetime(2005, 6, 4, 22, 32), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (965, datetime.datetime(2005, 5, 30, 19, 0), 3363, 502, datetime.datetime(2005, 5, 31, 17, 10), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (966, datetime.datetime(2005, 5, 30, 19, 0), 1294, 496, datetime.datetime(2005, 5, 31, 23, 51), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (967, datetime.datetime(2005, 5, 30, 19, 12), 1954, 330, datetime.datetime(2005, 6, 9, 0, 2), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (968, datetime.datetime(2005, 5, 30, 19, 20), 119, 576, datetime.datetime(2005, 5, 31, 18, 17), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (969, datetime.datetime(2005, 5, 30, 19, 23), 443, 551, datetime.datetime(2005, 5, 31, 21, 14), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (970, datetime.datetime(2005, 5, 30, 19, 50), 1520, 307, datetime.datetime(2005, 6, 9, 1, 19), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (971, datetime.datetime(2005, 5, 30, 20, 10), 2911, 561, datetime.datetime(2005, 6, 6, 20, 47), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (972, datetime.datetime(2005, 5, 30, 20, 21), 2, 411, datetime.datetime(2005, 6, 6, 0, 36), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (973, datetime.datetime(2005, 5, 30, 20, 27), 1914, 473, datetime.datetime(2005, 6, 8, 22, 47), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (974, datetime.datetime(2005, 5, 30, 20, 28), 2617, 596, datetime.datetime(2005, 6, 8, 23, 45), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (975, datetime.datetime(2005, 5, 30, 21, 7), 3109, 7, datetime.datetime(2005, 6, 3, 1, 48), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (976, datetime.datetime(2005, 5, 30, 21, 11), 2290, 581, datetime.datetime(2005, 6, 6, 2, 16), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (977, datetime.datetime(2005, 5, 30, 21, 22), 2029, 394, datetime.datetime(2005, 6, 4, 22, 32), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (978, datetime.datetime(2005, 5, 30, 21, 30), 407, 154, datetime.datetime(2005, 6, 7, 16, 22), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (979, datetime.datetime(2005, 5, 30, 21, 37), 3917, 279, datetime.datetime(2005, 6, 8, 0, 24), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (980, datetime.datetime(2005, 5, 30, 21, 45), 4169, 273, datetime.datetime(2005, 6, 1, 20, 32), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (981, datetime.datetime(2005, 5, 30, 21, 52), 2913, 326, datetime.datetime(2005, 6, 1, 3, 15), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (982, datetime.datetime(2005, 5, 30, 22, 15), 3560, 524, datetime.datetime(2005, 6, 2, 16, 18), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (983, datetime.datetime(2005, 5, 30, 22, 15), 63, 115, datetime.datetime(2005, 6, 2, 22, 56), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (984, datetime.datetime(2005, 5, 30, 22, 17), 2305, 262, datetime.datetime(2005, 6, 1, 20, 15), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (985, datetime.datetime(2005, 5, 30, 22, 18), 1573, 564, datetime.datetime(2005, 6, 4, 23, 36), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (986, datetime.datetime(2005, 5, 30, 22, 22), 4045, 253, datetime.datetime(2005, 6, 1, 2, 24), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (987, datetime.datetime(2005, 5, 30, 22, 59), 390, 11, datetime.datetime(2005, 6, 7, 20, 56), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (988, datetime.datetime(2005, 5, 30, 23, 8), 1364, 12, datetime.datetime(2005, 6, 7, 0, 22), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (989, datetime.datetime(2005, 5, 30, 23, 11), 4388, 83, datetime.datetime(2005, 6, 3, 20, 36), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (990, datetime.datetime(2005, 5, 30, 23, 25), 4171, 311, datetime.datetime(2005, 6, 6, 18, 41), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (991, datetime.datetime(2005, 5, 30, 23, 29), 2863, 593, datetime.datetime(2005, 6, 7, 23, 16), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (992, datetime.datetime(2005, 5, 30, 23, 47), 3572, 123, datetime.datetime(2005, 6, 5, 19, 1), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (993, datetime.datetime(2005, 5, 30, 23, 54), 2080, 513, datetime.datetime(2005, 6, 4, 21, 27), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (994, datetime.datetime(2005, 5, 30, 23, 55), 2798, 472, datetime.datetime(2005, 6, 4, 1, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (995, datetime.datetime(2005, 5, 31, 0, 6), 17, 150, datetime.datetime(2005, 6, 6, 2, 30), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (996, datetime.datetime(2005, 5, 31, 0, 6), 2075, 331, datetime.datetime(2005, 5, 31, 21, 29), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (997, datetime.datetime(2005, 5, 31, 0, 8), 4243, 216, datetime.datetime(2005, 6, 2, 0, 17), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (998, datetime.datetime(2005, 5, 31, 0, 16), 3395, 389, datetime.datetime(2005, 6, 1, 22, 41), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (999, datetime.datetime(2005, 5, 31, 0, 25), 4433, 413, datetime.datetime(2005, 6, 3, 6, 5), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (1000, datetime.datetime(2005, 5, 31, 0, 25), 1774, 332, datetime.datetime(2005, 6, 8, 19, 42), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (1001, datetime.datetime(2005, 5, 31, 0, 46), 1498, 64, datetime.datetime(2005, 6, 6, 6, 14), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  ...]

# %%
# %%sql
# select * from rental order by rental_id
# Out:
#  * postgresql://localhost/postgres
# 16044 rows affected.
# [(1, datetime.datetime(2005, 5, 24, 22, 53), 367, 130, datetime.datetime(2005, 5, 26, 22, 4), 1, datetime.datetime(2006, 2, 15, 21, 30)),
#  (2, datetime.datetime(2005, 5, 24, 22, 54), 1525, 459, datetime.datetime(2005, 5, 28, 19, 40), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (3, datetime.datetime(2005, 5, 24, 23, 3), 1711, 408, datetime.datetime(2005, 6, 1, 22, 12), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (4, datetime.datetime(2005, 5, 24, 23, 4), 2452, 333, datetime.datetime(2005, 6, 3, 1, 43), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (5, datetime.datetime(2005, 5, 24, 23, 5), 2079, 222, datetime.datetime(2005, 6, 2, 4, 33), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (6, datetime.datetime(2005, 5, 24, 23, 8), 2792, 549, datetime.datetime(2005, 5, 27, 1, 32), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (7, datetime.datetime(2005, 5, 24, 23, 11), 3995, 269, datetime.datetime(2005, 5, 29, 20, 34), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (8, datetime.datetime(2005, 5, 24, 23, 31), 2346, 239, datetime.datetime(2005, 5, 27, 23, 33), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (9, datetime.datetime(2005, 5, 25, 0, 0), 2580, 126, datetime.datetime(2005, 5, 28, 0, 22), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (10, datetime.datetime(2005, 5, 25, 0, 2), 1824, 399, datetime.datetime(2005, 5, 31, 22, 44), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (11, datetime.datetime(2005, 5, 25, 0, 9), 4443, 142, datetime.datetime(2005, 6, 2, 20, 56), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (12, datetime.datetime(2005, 5, 25, 0, 19), 1584, 261, datetime.datetime(2005, 5, 30, 5, 44), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (13, datetime.datetime(2005, 5, 25, 0, 22), 2294, 334, datetime.datetime(2005, 5, 30, 4, 28), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (14, datetime.datetime(2005, 5, 25, 0, 31), 2701, 446, datetime.datetime(2005, 5, 26, 2, 56), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (15, datetime.datetime(2005, 5, 25, 0, 39), 3049, 319, datetime.datetime(2005, 6, 3, 3, 30), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (16, datetime.datetime(2005, 5, 25, 0, 43), 389, 316, datetime.datetime(2005, 5, 26, 4, 42), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (17, datetime.datetime(2005, 5, 25, 1, 6), 830, 575, datetime.datetime(2005, 5, 27, 0, 43), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (18, datetime.datetime(2005, 5, 25, 1, 10), 3376, 19, datetime.datetime(2005, 5, 31, 6, 35), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (19, datetime.datetime(2005, 5, 25, 1, 17), 1941, 456, datetime.datetime(2005, 5, 31, 6, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (20, datetime.datetime(2005, 5, 25, 1, 48), 3517, 185, datetime.datetime(2005, 5, 27, 2, 20), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (21, datetime.datetime(2005, 5, 25, 1, 59), 146, 388, datetime.datetime(2005, 5, 26, 1, 1), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (22, datetime.datetime(2005, 5, 25, 2, 19), 727, 509, datetime.datetime(2005, 5, 26, 4, 52), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (23, datetime.datetime(2005, 5, 25, 2, 40), 4441, 438, datetime.datetime(2005, 5, 29, 6, 34), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (24, datetime.datetime(2005, 5, 25, 2, 53), 3273, 350, datetime.datetime(2005, 5, 27, 1, 15), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (25, datetime.datetime(2005, 5, 25, 3, 21), 3961, 37, datetime.datetime(2005, 5, 27, 21, 25), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (26, datetime.datetime(2005, 5, 25, 3, 36), 4371, 371, datetime.datetime(2005, 5, 31, 0, 34), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (27, datetime.datetime(2005, 5, 25, 3, 41), 1225, 301, datetime.datetime(2005, 5, 30, 1, 13), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (28, datetime.datetime(2005, 5, 25, 3, 42), 4068, 232, datetime.datetime(2005, 5, 26, 9, 26), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (29, datetime.datetime(2005, 5, 25, 3, 47), 611, 44, datetime.datetime(2005, 5, 30, 0, 31), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (30, datetime.datetime(2005, 5, 25, 4, 1), 3744, 430, datetime.datetime(2005, 5, 30, 3, 12), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (31, datetime.datetime(2005, 5, 25, 4, 5), 4482, 369, datetime.datetime(2005, 5, 30, 7, 15), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (32, datetime.datetime(2005, 5, 25, 4, 6), 3832, 230, datetime.datetime(2005, 5, 25, 23, 55), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (33, datetime.datetime(2005, 5, 25, 4, 18), 1681, 272, datetime.datetime(2005, 5, 27, 3, 58), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (34, datetime.datetime(2005, 5, 25, 4, 19), 2613, 597, datetime.datetime(2005, 5, 29, 0, 10), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (35, datetime.datetime(2005, 5, 25, 4, 24), 1286, 484, datetime.datetime(2005, 5, 27, 7, 2), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (36, datetime.datetime(2005, 5, 25, 4, 36), 1308, 88, datetime.datetime(2005, 5, 29, 0, 31), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (37, datetime.datetime(2005, 5, 25, 4, 44), 403, 535, datetime.datetime(2005, 5, 29, 1, 3), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (38, datetime.datetime(2005, 5, 25, 4, 47), 2540, 302, datetime.datetime(2005, 6, 1, 0, 58), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (39, datetime.datetime(2005, 5, 25, 4, 51), 4466, 207, datetime.datetime(2005, 5, 31, 3, 14), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (40, datetime.datetime(2005, 5, 25, 5, 9), 2638, 413, datetime.datetime(2005, 5, 27, 23, 12), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (41, datetime.datetime(2005, 5, 25, 5, 12), 1761, 174, datetime.datetime(2005, 6, 2, 0, 28), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (42, datetime.datetime(2005, 5, 25, 5, 24), 380, 523, datetime.datetime(2005, 5, 31, 2, 47), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (43, datetime.datetime(2005, 5, 25, 5, 39), 2578, 532, datetime.datetime(2005, 5, 26, 6, 54), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (44, datetime.datetime(2005, 5, 25, 5, 53), 3098, 207, datetime.datetime(2005, 5, 29, 10, 56), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (45, datetime.datetime(2005, 5, 25, 5, 59), 1853, 436, datetime.datetime(2005, 6, 2, 9, 56), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (46, datetime.datetime(2005, 5, 25, 6, 4), 3318, 7, datetime.datetime(2005, 6, 2, 8, 18), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (47, datetime.datetime(2005, 5, 25, 6, 5), 2211, 35, datetime.datetime(2005, 5, 30, 3, 4), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (48, datetime.datetime(2005, 5, 25, 6, 20), 1780, 282, datetime.datetime(2005, 6, 2, 5, 42), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (49, datetime.datetime(2005, 5, 25, 6, 39), 2965, 498, datetime.datetime(2005, 5, 30, 10, 12), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (50, datetime.datetime(2005, 5, 25, 6, 44), 1983, 18, datetime.datetime(2005, 5, 28, 11, 28), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (51, datetime.datetime(2005, 5, 25, 6, 49), 1257, 256, datetime.datetime(2005, 5, 26, 6, 42), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (52, datetime.datetime(2005, 5, 25, 6, 51), 4017, 507, datetime.datetime(2005, 5, 31, 1, 27), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (53, datetime.datetime(2005, 5, 25, 7, 19), 1255, 569, datetime.datetime(2005, 5, 27, 5, 19), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (54, datetime.datetime(2005, 5, 25, 7, 23), 2787, 291, datetime.datetime(2005, 6, 1, 5, 5), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (55, datetime.datetime(2005, 5, 25, 8, 26), 1139, 131, datetime.datetime(2005, 5, 30, 10, 57), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (56, datetime.datetime(2005, 5, 25, 8, 28), 1352, 511, datetime.datetime(2005, 5, 26, 14, 21), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (57, datetime.datetime(2005, 5, 25, 8, 43), 3938, 6, datetime.datetime(2005, 5, 29, 6, 42), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (58, datetime.datetime(2005, 5, 25, 8, 53), 3050, 323, datetime.datetime(2005, 5, 28, 14, 40), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (59, datetime.datetime(2005, 5, 25, 8, 56), 2884, 408, datetime.datetime(2005, 6, 1, 9, 52), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (60, datetime.datetime(2005, 5, 25, 8, 58), 330, 470, datetime.datetime(2005, 5, 30, 14, 14), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (61, datetime.datetime(2005, 5, 25, 9, 1), 4210, 250, datetime.datetime(2005, 6, 2, 7, 22), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (62, datetime.datetime(2005, 5, 25, 9, 18), 261, 419, datetime.datetime(2005, 5, 30, 10, 55), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (63, datetime.datetime(2005, 5, 25, 9, 19), 4008, 383, datetime.datetime(2005, 5, 27, 4, 24), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (64, datetime.datetime(2005, 5, 25, 9, 21), 79, 368, datetime.datetime(2005, 6, 3, 11, 31), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (65, datetime.datetime(2005, 5, 25, 9, 32), 3552, 346, datetime.datetime(2005, 5, 29, 14, 21), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (66, datetime.datetime(2005, 5, 25, 9, 35), 1162, 86, datetime.datetime(2005, 5, 29, 4, 16), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (67, datetime.datetime(2005, 5, 25, 9, 41), 239, 119, datetime.datetime(2005, 5, 27, 13, 46), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (68, datetime.datetime(2005, 5, 25, 9, 47), 4029, 120, datetime.datetime(2005, 5, 31, 10, 20), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (69, datetime.datetime(2005, 5, 25, 10, 10), 3207, 305, datetime.datetime(2005, 5, 27, 14, 2), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (70, datetime.datetime(2005, 5, 25, 10, 15), 2168, 73, datetime.datetime(2005, 5, 27, 5, 56), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (71, datetime.datetime(2005, 5, 25, 10, 26), 2408, 100, datetime.datetime(2005, 5, 28, 4, 59), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (72, datetime.datetime(2005, 5, 25, 10, 52), 2260, 48, datetime.datetime(2005, 5, 28, 5, 52), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (73, datetime.datetime(2005, 5, 25, 11, 0), 517, 391, datetime.datetime(2005, 6, 1, 13, 56), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (74, datetime.datetime(2005, 5, 25, 11, 9), 1744, 265, datetime.datetime(2005, 5, 26, 12, 23), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (75, datetime.datetime(2005, 5, 25, 11, 13), 3393, 510, datetime.datetime(2005, 6, 3, 12, 58), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (76, datetime.datetime(2005, 5, 25, 11, 30), 3021, 1, datetime.datetime(2005, 6, 3, 12, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (77, datetime.datetime(2005, 5, 25, 11, 31), 1303, 451, datetime.datetime(2005, 5, 26, 16, 53), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (78, datetime.datetime(2005, 5, 25, 11, 35), 4067, 135, datetime.datetime(2005, 5, 31, 12, 48), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (79, datetime.datetime(2005, 5, 25, 12, 11), 3299, 245, datetime.datetime(2005, 6, 3, 10, 54), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (80, datetime.datetime(2005, 5, 25, 12, 12), 2478, 314, datetime.datetime(2005, 5, 31, 17, 46), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (81, datetime.datetime(2005, 5, 25, 12, 15), 2610, 286, datetime.datetime(2005, 6, 2, 14, 8), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (82, datetime.datetime(2005, 5, 25, 12, 17), 1388, 427, datetime.datetime(2005, 6, 1, 10, 48), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (83, datetime.datetime(2005, 5, 25, 12, 30), 466, 131, datetime.datetime(2005, 5, 27, 15, 40), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (84, datetime.datetime(2005, 5, 25, 12, 36), 1829, 492, datetime.datetime(2005, 5, 29, 18, 33), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (85, datetime.datetime(2005, 5, 25, 13, 5), 470, 414, datetime.datetime(2005, 5, 29, 16, 53), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (86, datetime.datetime(2005, 5, 25, 13, 36), 2275, 266, datetime.datetime(2005, 5, 30, 14, 53), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (87, datetime.datetime(2005, 5, 25, 13, 52), 1586, 331, datetime.datetime(2005, 5, 29, 11, 12), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (88, datetime.datetime(2005, 5, 25, 14, 13), 2221, 53, datetime.datetime(2005, 5, 29, 9, 32), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (89, datetime.datetime(2005, 5, 25, 14, 28), 2181, 499, datetime.datetime(2005, 5, 29, 14, 33), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (90, datetime.datetime(2005, 5, 25, 14, 31), 2984, 25, datetime.datetime(2005, 6, 1, 10, 7), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (91, datetime.datetime(2005, 5, 25, 14, 57), 139, 267, datetime.datetime(2005, 6, 1, 18, 32), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (92, datetime.datetime(2005, 5, 25, 15, 38), 775, 302, datetime.datetime(2005, 5, 31, 13, 40), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (93, datetime.datetime(2005, 5, 25, 15, 54), 4360, 288, datetime.datetime(2005, 6, 3, 20, 18), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (94, datetime.datetime(2005, 5, 25, 16, 3), 1675, 197, datetime.datetime(2005, 5, 30, 14, 23), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (95, datetime.datetime(2005, 5, 25, 16, 12), 178, 400, datetime.datetime(2005, 6, 2, 18, 55), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (96, datetime.datetime(2005, 5, 25, 16, 32), 3418, 49, datetime.datetime(2005, 5, 30, 10, 47), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (97, datetime.datetime(2005, 5, 25, 16, 34), 1283, 263, datetime.datetime(2005, 5, 28, 12, 13), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (98, datetime.datetime(2005, 5, 25, 16, 48), 2970, 269, datetime.datetime(2005, 5, 27, 11, 29), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (99, datetime.datetime(2005, 5, 25, 16, 50), 535, 44, datetime.datetime(2005, 5, 28, 18, 52), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (100, datetime.datetime(2005, 5, 25, 16, 50), 2599, 208, datetime.datetime(2005, 6, 2, 22, 11), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (101, datetime.datetime(2005, 5, 25, 17, 17), 617, 468, datetime.datetime(2005, 5, 31, 19, 47), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (102, datetime.datetime(2005, 5, 25, 17, 22), 373, 343, datetime.datetime(2005, 5, 31, 19, 47), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (103, datetime.datetime(2005, 5, 25, 17, 30), 3343, 384, datetime.datetime(2005, 6, 3, 22, 36), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (104, datetime.datetime(2005, 5, 25, 17, 46), 4281, 310, datetime.datetime(2005, 5, 27, 15, 20), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (105, datetime.datetime(2005, 5, 25, 17, 54), 794, 108, datetime.datetime(2005, 5, 30, 12, 3), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (106, datetime.datetime(2005, 5, 25, 18, 18), 3627, 196, datetime.datetime(2005, 6, 4, 0, 1), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (107, datetime.datetime(2005, 5, 25, 18, 28), 2833, 317, datetime.datetime(2005, 6, 3, 22, 46), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (108, datetime.datetime(2005, 5, 25, 18, 30), 3289, 242, datetime.datetime(2005, 5, 30, 19, 40), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (109, datetime.datetime(2005, 5, 25, 18, 40), 1044, 503, datetime.datetime(2005, 5, 29, 20, 39), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (110, datetime.datetime(2005, 5, 25, 18, 43), 4108, 19, datetime.datetime(2005, 6, 3, 18, 13), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (111, datetime.datetime(2005, 5, 25, 18, 45), 3725, 227, datetime.datetime(2005, 5, 28, 17, 18), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (112, datetime.datetime(2005, 5, 25, 18, 57), 2153, 500, datetime.datetime(2005, 6, 2, 20, 44), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (113, datetime.datetime(2005, 5, 25, 19, 7), 2963, 93, datetime.datetime(2005, 5, 27, 22, 16), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (114, datetime.datetime(2005, 5, 25, 19, 12), 4502, 506, datetime.datetime(2005, 6, 1, 23, 10), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (115, datetime.datetime(2005, 5, 25, 19, 13), 749, 455, datetime.datetime(2005, 5, 29, 20, 17), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (116, datetime.datetime(2005, 5, 25, 19, 27), 4453, 18, datetime.datetime(2005, 5, 26, 16, 23), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (117, datetime.datetime(2005, 5, 25, 19, 30), 4278, 7, datetime.datetime(2005, 5, 31, 23, 59), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (118, datetime.datetime(2005, 5, 25, 19, 31), 872, 524, datetime.datetime(2005, 5, 31, 15, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (119, datetime.datetime(2005, 5, 25, 19, 37), 1359, 51, datetime.datetime(2005, 5, 29, 23, 51), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (120, datetime.datetime(2005, 5, 25, 19, 37), 37, 365, datetime.datetime(2005, 6, 1, 23, 29), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (121, datetime.datetime(2005, 5, 25, 19, 41), 1053, 405, datetime.datetime(2005, 5, 29, 21, 31), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (122, datetime.datetime(2005, 5, 25, 19, 46), 2908, 273, datetime.datetime(2005, 6, 2, 19, 7), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (123, datetime.datetime(2005, 5, 25, 20, 26), 1795, 43, datetime.datetime(2005, 5, 26, 19, 41), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (124, datetime.datetime(2005, 5, 25, 20, 46), 212, 246, datetime.datetime(2005, 5, 30, 0, 47), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (125, datetime.datetime(2005, 5, 25, 20, 48), 952, 368, datetime.datetime(2005, 6, 2, 21, 39), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (126, datetime.datetime(2005, 5, 25, 21, 7), 2047, 439, datetime.datetime(2005, 5, 28, 18, 51), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (127, datetime.datetime(2005, 5, 25, 21, 10), 2026, 94, datetime.datetime(2005, 6, 2, 21, 38), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (128, datetime.datetime(2005, 5, 25, 21, 19), 4322, 40, datetime.datetime(2005, 5, 29, 23, 34), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (129, datetime.datetime(2005, 5, 25, 21, 20), 4154, 23, datetime.datetime(2005, 6, 4, 1, 25), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (130, datetime.datetime(2005, 5, 25, 21, 21), 3990, 56, datetime.datetime(2005, 5, 30, 22, 41), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (131, datetime.datetime(2005, 5, 25, 21, 42), 815, 325, datetime.datetime(2005, 5, 30, 23, 25), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (132, datetime.datetime(2005, 5, 25, 21, 46), 3367, 479, datetime.datetime(2005, 5, 31, 21, 2), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (133, datetime.datetime(2005, 5, 25, 21, 48), 399, 237, datetime.datetime(2005, 5, 30, 0, 26), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (134, datetime.datetime(2005, 5, 25, 21, 48), 2272, 222, datetime.datetime(2005, 6, 2, 18, 28), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (135, datetime.datetime(2005, 5, 25, 21, 58), 103, 304, datetime.datetime(2005, 6, 3, 17, 50), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (136, datetime.datetime(2005, 5, 25, 22, 2), 2296, 504, datetime.datetime(2005, 5, 31, 18, 6), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (137, datetime.datetime(2005, 5, 25, 22, 25), 2591, 560, datetime.datetime(2005, 6, 1, 2, 30), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (138, datetime.datetime(2005, 5, 25, 22, 48), 4134, 586, datetime.datetime(2005, 5, 29, 20, 21), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (139, datetime.datetime(2005, 5, 25, 23, 0), 327, 257, datetime.datetime(2005, 5, 29, 17, 12), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (140, datetime.datetime(2005, 5, 25, 23, 34), 655, 354, datetime.datetime(2005, 5, 27, 1, 10), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (141, datetime.datetime(2005, 5, 25, 23, 34), 811, 89, datetime.datetime(2005, 6, 2, 1, 57), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (142, datetime.datetime(2005, 5, 25, 23, 43), 4407, 472, datetime.datetime(2005, 5, 29, 0, 46), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (143, datetime.datetime(2005, 5, 25, 23, 45), 847, 297, datetime.datetime(2005, 5, 27, 21, 41), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (144, datetime.datetime(2005, 5, 25, 23, 49), 1689, 357, datetime.datetime(2005, 6, 1, 21, 41), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (145, datetime.datetime(2005, 5, 25, 23, 59), 3905, 82, datetime.datetime(2005, 5, 31, 2, 56), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (146, datetime.datetime(2005, 5, 26, 0, 7), 1431, 433, datetime.datetime(2005, 6, 4, 0, 20), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (147, datetime.datetime(2005, 5, 26, 0, 17), 633, 274, datetime.datetime(2005, 5, 29, 23, 21), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (148, datetime.datetime(2005, 5, 26, 0, 25), 4252, 142, datetime.datetime(2005, 6, 1, 19, 29), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (149, datetime.datetime(2005, 5, 26, 0, 28), 1084, 319, datetime.datetime(2005, 6, 2, 21, 30), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (150, datetime.datetime(2005, 5, 26, 0, 28), 909, 429, datetime.datetime(2005, 6, 1, 2, 10), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (151, datetime.datetime(2005, 5, 26, 0, 37), 2942, 14, datetime.datetime(2005, 5, 30, 6, 28), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (152, datetime.datetime(2005, 5, 26, 0, 41), 2622, 57, datetime.datetime(2005, 6, 3, 6, 5), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (153, datetime.datetime(2005, 5, 26, 0, 47), 3888, 348, datetime.datetime(2005, 5, 27, 21, 28), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (154, datetime.datetime(2005, 5, 26, 0, 55), 1354, 185, datetime.datetime(2005, 5, 29, 23, 18), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (155, datetime.datetime(2005, 5, 26, 1, 15), 288, 551, datetime.datetime(2005, 6, 1, 0, 3), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (156, datetime.datetime(2005, 5, 26, 1, 19), 3193, 462, datetime.datetime(2005, 5, 27, 23, 43), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (157, datetime.datetime(2005, 5, 26, 1, 25), 887, 344, datetime.datetime(2005, 5, 26, 21, 17), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (158, datetime.datetime(2005, 5, 26, 1, 27), 2395, 354, datetime.datetime(2005, 6, 3, 0, 30), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (159, datetime.datetime(2005, 5, 26, 1, 34), 3453, 505, datetime.datetime(2005, 5, 29, 4, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (160, datetime.datetime(2005, 5, 26, 1, 46), 1885, 290, datetime.datetime(2005, 6, 1, 5, 45), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (161, datetime.datetime(2005, 5, 26, 1, 51), 2941, 182, datetime.datetime(2005, 5, 27, 5, 42), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (162, datetime.datetime(2005, 5, 26, 2, 2), 1229, 296, datetime.datetime(2005, 5, 27, 3, 38), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (163, datetime.datetime(2005, 5, 26, 2, 26), 2306, 104, datetime.datetime(2005, 6, 4, 6, 36), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (164, datetime.datetime(2005, 5, 26, 2, 26), 1070, 151, datetime.datetime(2005, 5, 28, 0, 32), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (165, datetime.datetime(2005, 5, 26, 2, 28), 2735, 33, datetime.datetime(2005, 6, 2, 3, 21), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (166, datetime.datetime(2005, 5, 26, 2, 49), 3894, 322, datetime.datetime(2005, 5, 31, 1, 28), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (167, datetime.datetime(2005, 5, 26, 2, 50), 865, 401, datetime.datetime(2005, 5, 27, 3, 7), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (168, datetime.datetime(2005, 5, 26, 3, 7), 2714, 469, datetime.datetime(2005, 6, 2, 2, 9), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (169, datetime.datetime(2005, 5, 26, 3, 9), 1758, 381, datetime.datetime(2005, 5, 27, 1, 37), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (170, datetime.datetime(2005, 5, 26, 3, 11), 3688, 107, datetime.datetime(2005, 6, 2, 3, 53), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (171, datetime.datetime(2005, 5, 26, 3, 14), 4483, 400, datetime.datetime(2005, 6, 3, 0, 24), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (172, datetime.datetime(2005, 5, 26, 3, 17), 2873, 176, datetime.datetime(2005, 5, 29, 4, 11), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  
 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (282, datetime.datetime(2005, 5, 26, 18, 56), 4486, 282, datetime.datetime(2005, 6, 1, 16, 32), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (283, datetime.datetime(2005, 5, 26, 19, 5), 3530, 242, datetime.datetime(2005, 5, 31, 19, 19), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (284, datetime.datetime(2005, 5, 26, 19, 21), 350, 359, datetime.datetime(2005, 6, 4, 14, 18), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (285, datetime.datetime(2005, 5, 26, 19, 41), 2486, 162, datetime.datetime(2005, 5, 31, 16, 58), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (286, datetime.datetime(2005, 5, 26, 19, 44), 314, 371, datetime.datetime(2005, 6, 4, 18, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (287, datetime.datetime(2005, 5, 26, 19, 44), 3631, 17, datetime.datetime(2005, 6, 2, 1, 10), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (288, datetime.datetime(2005, 5, 26, 19, 47), 3546, 82, datetime.datetime(2005, 6, 3, 20, 53), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (289, datetime.datetime(2005, 5, 26, 20, 1), 2449, 81, datetime.datetime(2005, 5, 28, 15, 9), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (290, datetime.datetime(2005, 5, 26, 20, 8), 2776, 429, datetime.datetime(2005, 5, 30, 0, 32), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (291, datetime.datetime(2005, 5, 26, 20, 20), 485, 577, datetime.datetime(2005, 6, 3, 2, 6), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (292, datetime.datetime(2005, 5, 26, 20, 22), 4264, 515, datetime.datetime(2005, 6, 5, 0, 58), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (293, datetime.datetime(2005, 5, 26, 20, 27), 1828, 158, datetime.datetime(2005, 6, 3, 16, 45), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (294, datetime.datetime(2005, 5, 26, 20, 29), 2751, 369, datetime.datetime(2005, 5, 28, 17, 20), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (295, datetime.datetime(2005, 5, 26, 20, 33), 4030, 65, datetime.datetime(2005, 5, 27, 18, 23), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (296, datetime.datetime(2005, 5, 26, 20, 35), 3878, 468, datetime.datetime(2005, 6, 4, 2, 31), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (297, datetime.datetime(2005, 5, 26, 20, 48), 1594, 48, datetime.datetime(2005, 5, 27, 19, 52), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (298, datetime.datetime(2005, 5, 26, 20, 52), 1083, 460, datetime.datetime(2005, 5, 29, 22, 8), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (299, datetime.datetime(2005, 5, 26, 20, 55), 4376, 448, datetime.datetime(2005, 5, 28, 0, 25), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (300, datetime.datetime(2005, 5, 26, 20, 57), 249, 47, datetime.datetime(2005, 6, 5, 1, 34), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (301, datetime.datetime(2005, 5, 26, 21, 6), 3448, 274, datetime.datetime(2005, 6, 1, 1, 54), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (302, datetime.datetime(2005, 5, 26, 21, 13), 2921, 387, datetime.datetime(2005, 6, 3, 15, 49), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (303, datetime.datetime(2005, 5, 26, 21, 16), 1111, 596, datetime.datetime(2005, 5, 27, 23, 41), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (304, datetime.datetime(2005, 5, 26, 21, 21), 1701, 534, datetime.datetime(2005, 6, 2, 0, 5), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (305, datetime.datetime(2005, 5, 26, 21, 22), 2665, 464, datetime.datetime(2005, 6, 2, 22, 33), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (306, datetime.datetime(2005, 5, 26, 21, 31), 2781, 547, datetime.datetime(2005, 5, 28, 19, 37), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (307, datetime.datetime(2005, 5, 26, 21, 48), 1097, 375, datetime.datetime(2005, 6, 4, 22, 24), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (308, datetime.datetime(2005, 5, 26, 22, 1), 187, 277, datetime.datetime(2005, 6, 4, 20, 24), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (309, datetime.datetime(2005, 5, 26, 22, 38), 1946, 251, datetime.datetime(2005, 6, 2, 3, 10), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (310, datetime.datetime(2005, 5, 26, 22, 41), 593, 409, datetime.datetime(2005, 6, 2, 4, 9), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (311, datetime.datetime(2005, 5, 26, 22, 51), 2830, 201, datetime.datetime(2005, 6, 1, 0, 2), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (312, datetime.datetime(2005, 5, 26, 22, 52), 2008, 143, datetime.datetime(2005, 6, 2, 18, 14), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (313, datetime.datetime(2005, 5, 26, 22, 56), 4156, 594, datetime.datetime(2005, 5, 29, 1, 29), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (314, datetime.datetime(2005, 5, 26, 23, 9), 2851, 203, datetime.datetime(2005, 5, 28, 22, 49), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (315, datetime.datetime(2005, 5, 26, 23, 12), 2847, 238, datetime.datetime(2005, 5, 29, 23, 33), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (316, datetime.datetime(2005, 5, 26, 23, 22), 3828, 249, datetime.datetime(2005, 5, 29, 23, 25), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (317, datetime.datetime(2005, 5, 26, 23, 23), 26, 391, datetime.datetime(2005, 6, 1, 19, 56), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (318, datetime.datetime(2005, 5, 26, 23, 37), 2559, 60, datetime.datetime(2005, 6, 3, 4, 31), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (319, datetime.datetime(2005, 5, 26, 23, 52), 3024, 77, datetime.datetime(2005, 5, 30, 18, 55), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (320, datetime.datetime(2005, 5, 27, 0, 9), 1090, 2, datetime.datetime(2005, 5, 28, 4, 30), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (322, datetime.datetime(2005, 5, 27, 0, 47), 4556, 496, datetime.datetime(2005, 6, 2, 0, 32), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (323, datetime.datetime(2005, 5, 27, 0, 49), 2362, 144, datetime.datetime(2005, 5, 30, 3, 12), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (324, datetime.datetime(2005, 5, 27, 1, 0), 3364, 292, datetime.datetime(2005, 5, 30, 4, 27), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (325, datetime.datetime(2005, 5, 27, 1, 9), 2510, 449, datetime.datetime(2005, 5, 31, 7, 1), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (326, datetime.datetime(2005, 5, 27, 1, 10), 3979, 432, datetime.datetime(2005, 6, 4, 20, 25), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (327, datetime.datetime(2005, 5, 27, 1, 18), 2678, 105, datetime.datetime(2005, 6, 4, 4, 6), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (328, datetime.datetime(2005, 5, 27, 1, 29), 2524, 451, datetime.datetime(2005, 6, 1, 2, 27), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (329, datetime.datetime(2005, 5, 27, 1, 57), 2659, 231, datetime.datetime(2005, 5, 31, 4, 19), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (330, datetime.datetime(2005, 5, 27, 2, 15), 1536, 248, datetime.datetime(2005, 6, 4, 5, 9), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (331, datetime.datetime(2005, 5, 27, 2, 22), 1872, 67, datetime.datetime(2005, 6, 5, 0, 25), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (332, datetime.datetime(2005, 5, 27, 2, 27), 1529, 299, datetime.datetime(2005, 6, 3, 1, 26), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (333, datetime.datetime(2005, 5, 27, 2, 52), 4001, 412, datetime.datetime(2005, 6, 1, 0, 55), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (334, datetime.datetime(2005, 5, 27, 3, 3), 3973, 194, datetime.datetime(2005, 5, 29, 3, 54), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (335, datetime.datetime(2005, 5, 27, 3, 7), 1411, 16, datetime.datetime(2005, 6, 5, 0, 15), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (336, datetime.datetime(2005, 5, 27, 3, 15), 1811, 275, datetime.datetime(2005, 5, 29, 22, 43), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (337, datetime.datetime(2005, 5, 27, 3, 22), 751, 19, datetime.datetime(2005, 6, 2, 3, 27), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (338, datetime.datetime(2005, 5, 27, 3, 42), 2596, 165, datetime.datetime(2005, 6, 1, 5, 23), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (339, datetime.datetime(2005, 5, 27, 3, 47), 2410, 516, datetime.datetime(2005, 6, 4, 5, 46), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (340, datetime.datetime(2005, 5, 27, 3, 55), 946, 209, datetime.datetime(2005, 6, 4, 7, 57), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (341, datetime.datetime(2005, 5, 27, 4, 1), 4168, 56, datetime.datetime(2005, 6, 5, 8, 51), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (342, datetime.datetime(2005, 5, 27, 4, 11), 4019, 539, datetime.datetime(2005, 5, 29, 1, 28), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (343, datetime.datetime(2005, 5, 27, 4, 13), 3301, 455, datetime.datetime(2005, 5, 28, 8, 34), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (344, datetime.datetime(2005, 5, 27, 4, 30), 2327, 236, datetime.datetime(2005, 5, 29, 10, 13), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (345, datetime.datetime(2005, 5, 27, 4, 32), 1396, 144, datetime.datetime(2005, 5, 31, 9, 50), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (346, datetime.datetime(2005, 5, 27, 4, 34), 4319, 14, datetime.datetime(2005, 6, 5, 4, 24), 2, datetime.datetime(2006, 2, 16, 2, 30)),
# ...
#  (887, datetime.datetime(2005, 5, 30, 7, 10), 2727, 16, datetime.datetime(2005, 6, 1, 6, 48), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (888, datetime.datetime(2005, 5, 30, 7, 13), 387, 128, datetime.datetime(2005, 6, 6, 9, 50), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (889, datetime.datetime(2005, 5, 30, 7, 14), 1299, 114, datetime.datetime(2005, 5, 31, 7, 56), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (890, datetime.datetime(2005, 5, 30, 7, 43), 1464, 349, datetime.datetime(2005, 6, 1, 11, 26), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (891, datetime.datetime(2005, 5, 30, 7, 43), 2611, 391, datetime.datetime(2005, 6, 8, 9, 21), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (892, datetime.datetime(2005, 5, 30, 8, 2), 471, 274, datetime.datetime(2005, 6, 5, 12, 51), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (893, datetime.datetime(2005, 5, 30, 8, 6), 3260, 502, datetime.datetime(2005, 6, 7, 8, 23), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (894, datetime.datetime(2005, 5, 30, 8, 31), 1118, 400, datetime.datetime(2005, 6, 7, 12, 39), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (895, datetime.datetime(2005, 5, 30, 8, 50), 2744, 192, datetime.datetime(2005, 6, 5, 10, 58), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (896, datetime.datetime(2005, 5, 30, 9, 3), 2817, 207, datetime.datetime(2005, 6, 5, 7, 37), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (897, datetime.datetime(2005, 5, 30, 9, 10), 1334, 432, datetime.datetime(2005, 6, 8, 3, 43), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (898, datetime.datetime(2005, 5, 30, 9, 26), 3497, 384, datetime.datetime(2005, 6, 1, 10, 45), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (899, datetime.datetime(2005, 5, 30, 9, 29), 1096, 156, datetime.datetime(2005, 6, 6, 12, 39), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (900, datetime.datetime(2005, 5, 30, 9, 38), 3543, 586, datetime.datetime(2005, 6, 7, 11, 54), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (901, datetime.datetime(2005, 5, 30, 9, 40), 760, 259, datetime.datetime(2005, 6, 2, 10, 32), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (902, datetime.datetime(2005, 5, 30, 9, 53), 1514, 561, datetime.datetime(2005, 6, 7, 12, 10), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (903, datetime.datetime(2005, 5, 30, 10, 11), 2423, 197, datetime.datetime(2005, 6, 3, 9, 33), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (904, datetime.datetime(2005, 5, 30, 10, 19), 2466, 44, datetime.datetime(2005, 6, 5, 4, 58), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (905, datetime.datetime(2005, 5, 30, 10, 25), 4372, 50, datetime.datetime(2005, 6, 6, 6, 23), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (906, datetime.datetime(2005, 5, 30, 10, 30), 1862, 549, datetime.datetime(2005, 6, 7, 6, 44), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (907, datetime.datetime(2005, 5, 30, 10, 37), 3320, 506, datetime.datetime(2005, 6, 2, 9, 51), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (908, datetime.datetime(2005, 5, 30, 10, 38), 4427, 85, datetime.datetime(2005, 6, 3, 9, 56), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (909, datetime.datetime(2005, 5, 30, 10, 43), 3775, 486, datetime.datetime(2005, 6, 8, 12, 7), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (910, datetime.datetime(2005, 5, 30, 10, 46), 2601, 374, datetime.datetime(2005, 6, 4, 13, 32), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (911, datetime.datetime(2005, 5, 30, 10, 50), 1404, 366, datetime.datetime(2005, 6, 7, 12, 26), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (912, datetime.datetime(2005, 5, 30, 10, 58), 3200, 390, datetime.datetime(2005, 5, 31, 9, 31), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (913, datetime.datetime(2005, 5, 30, 11, 4), 3213, 369, datetime.datetime(2005, 6, 7, 13, 22), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (914, datetime.datetime(2005, 5, 30, 11, 6), 1393, 596, datetime.datetime(2005, 6, 4, 6, 7), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (915, datetime.datetime(2005, 5, 30, 11, 20), 1859, 115, datetime.datetime(2005, 6, 2, 11, 55), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (916, datetime.datetime(2005, 5, 30, 11, 25), 1290, 6, datetime.datetime(2005, 5, 31, 9, 6), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (917, datetime.datetime(2005, 5, 30, 11, 27), 3629, 385, datetime.datetime(2005, 6, 2, 8, 31), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (918, datetime.datetime(2005, 5, 30, 11, 32), 818, 197, datetime.datetime(2005, 5, 31, 7, 55), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (919, datetime.datetime(2005, 5, 30, 11, 35), 4052, 374, datetime.datetime(2005, 6, 2, 13, 16), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (920, datetime.datetime(2005, 5, 30, 11, 44), 3860, 584, datetime.datetime(2005, 6, 2, 8, 19), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (921, datetime.datetime(2005, 5, 30, 11, 53), 1827, 508, datetime.datetime(2005, 6, 3, 10, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (922, datetime.datetime(2005, 5, 30, 11, 55), 2442, 550, datetime.datetime(2005, 6, 8, 10, 12), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (923, datetime.datetime(2005, 5, 30, 11, 58), 1884, 37, datetime.datetime(2005, 6, 5, 9, 57), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (924, datetime.datetime(2005, 5, 30, 12, 10), 3279, 293, datetime.datetime(2005, 6, 4, 17, 28), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (925, datetime.datetime(2005, 5, 30, 12, 13), 3203, 137, datetime.datetime(2005, 6, 2, 14, 41), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (926, datetime.datetime(2005, 5, 30, 12, 15), 4327, 76, datetime.datetime(2005, 6, 1, 8, 53), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (927, datetime.datetime(2005, 5, 30, 12, 16), 1158, 167, datetime.datetime(2005, 5, 31, 16, 20), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (928, datetime.datetime(2005, 5, 30, 12, 27), 246, 79, datetime.datetime(2005, 6, 5, 13, 56), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (929, datetime.datetime(2005, 5, 30, 12, 32), 4296, 536, datetime.datetime(2005, 6, 6, 12, 17), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (930, datetime.datetime(2005, 5, 30, 12, 44), 2835, 141, datetime.datetime(2005, 6, 4, 10, 53), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (931, datetime.datetime(2005, 5, 30, 12, 53), 3384, 421, datetime.datetime(2005, 5, 31, 14, 28), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (932, datetime.datetime(2005, 5, 30, 12, 55), 719, 198, datetime.datetime(2005, 5, 31, 10, 30), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (933, datetime.datetime(2005, 5, 30, 13, 8), 3672, 66, datetime.datetime(2005, 6, 1, 18, 56), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (934, datetime.datetime(2005, 5, 30, 13, 24), 3595, 60, datetime.datetime(2005, 6, 8, 16, 44), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (935, datetime.datetime(2005, 5, 30, 13, 29), 2421, 256, datetime.datetime(2005, 6, 2, 11, 8), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (936, datetime.datetime(2005, 5, 30, 13, 52), 901, 469, datetime.datetime(2005, 6, 7, 16, 56), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (937, datetime.datetime(2005, 5, 30, 14, 47), 1054, 304, datetime.datetime(2005, 6, 5, 9, 53), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (938, datetime.datetime(2005, 5, 30, 14, 47), 1521, 46, datetime.datetime(2005, 6, 4, 10, 10), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (939, datetime.datetime(2005, 5, 30, 14, 49), 1314, 367, datetime.datetime(2005, 6, 1, 19, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (940, datetime.datetime(2005, 5, 30, 15, 1), 1278, 534, datetime.datetime(2005, 6, 1, 18, 26), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (941, datetime.datetime(2005, 5, 30, 15, 2), 3630, 562, datetime.datetime(2005, 6, 1, 17, 19), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (942, datetime.datetime(2005, 5, 30, 15, 5), 4279, 473, datetime.datetime(2005, 6, 8, 15, 59), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (943, datetime.datetime(2005, 5, 30, 15, 20), 3737, 57, datetime.datetime(2005, 6, 6, 18, 53), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (944, datetime.datetime(2005, 5, 30, 15, 26), 151, 131, datetime.datetime(2005, 6, 7, 18, 9), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (945, datetime.datetime(2005, 5, 30, 15, 33), 1441, 357, datetime.datetime(2005, 6, 2, 15, 2), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (946, datetime.datetime(2005, 5, 30, 15, 35), 1264, 486, datetime.datetime(2005, 6, 8, 11, 38), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (947, datetime.datetime(2005, 5, 30, 15, 36), 4478, 62, datetime.datetime(2005, 6, 4, 18, 48), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (948, datetime.datetime(2005, 5, 30, 15, 44), 585, 245, datetime.datetime(2005, 6, 8, 17, 30), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (949, datetime.datetime(2005, 5, 30, 15, 50), 2202, 368, datetime.datetime(2005, 6, 3, 14, 25), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (950, datetime.datetime(2005, 5, 30, 16, 6), 491, 83, datetime.datetime(2005, 6, 1, 11, 43), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (951, datetime.datetime(2005, 5, 30, 16, 10), 1395, 59, datetime.datetime(2005, 5, 31, 19, 1), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (952, datetime.datetime(2005, 5, 30, 16, 28), 4389, 311, datetime.datetime(2005, 6, 2, 16, 12), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (953, datetime.datetime(2005, 5, 30, 16, 34), 2194, 210, datetime.datetime(2005, 5, 31, 20, 34), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (954, datetime.datetime(2005, 5, 30, 16, 57), 1231, 297, datetime.datetime(2005, 6, 8, 13, 30), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (955, datetime.datetime(2005, 5, 30, 16, 59), 4140, 301, datetime.datetime(2005, 5, 31, 11, 58), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (956, datetime.datetime(2005, 5, 30, 17, 30), 647, 296, datetime.datetime(2005, 6, 7, 13, 54), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (957, datetime.datetime(2005, 5, 30, 17, 53), 4428, 440, datetime.datetime(2005, 6, 3, 15, 31), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (958, datetime.datetime(2005, 5, 30, 17, 58), 548, 186, datetime.datetime(2005, 6, 1, 19, 17), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (959, datetime.datetime(2005, 5, 30, 18, 7), 3108, 535, datetime.datetime(2005, 6, 2, 14, 37), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (960, datetime.datetime(2005, 5, 30, 18, 13), 1966, 445, datetime.datetime(2005, 6, 4, 0, 12), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (961, datetime.datetime(2005, 5, 30, 18, 16), 3293, 588, datetime.datetime(2005, 6, 4, 23, 40), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (962, datetime.datetime(2005, 5, 30, 18, 45), 4535, 520, datetime.datetime(2005, 6, 5, 22, 47), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (963, datetime.datetime(2005, 5, 30, 18, 52), 1921, 225, datetime.datetime(2005, 6, 7, 16, 19), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (964, datetime.datetime(2005, 5, 30, 18, 53), 657, 287, datetime.datetime(2005, 6, 4, 22, 32), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (965, datetime.datetime(2005, 5, 30, 19, 0), 3363, 502, datetime.datetime(2005, 5, 31, 17, 10), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (966, datetime.datetime(2005, 5, 30, 19, 0), 1294, 496, datetime.datetime(2005, 5, 31, 23, 51), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (967, datetime.datetime(2005, 5, 30, 19, 12), 1954, 330, datetime.datetime(2005, 6, 9, 0, 2), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (968, datetime.datetime(2005, 5, 30, 19, 20), 119, 576, datetime.datetime(2005, 5, 31, 18, 17), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (969, datetime.datetime(2005, 5, 30, 19, 23), 443, 551, datetime.datetime(2005, 5, 31, 21, 14), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (970, datetime.datetime(2005, 5, 30, 19, 50), 1520, 307, datetime.datetime(2005, 6, 9, 1, 19), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (971, datetime.datetime(2005, 5, 30, 20, 10), 2911, 561, datetime.datetime(2005, 6, 6, 20, 47), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (972, datetime.datetime(2005, 5, 30, 20, 21), 2, 411, datetime.datetime(2005, 6, 6, 0, 36), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (973, datetime.datetime(2005, 5, 30, 20, 27), 1914, 473, datetime.datetime(2005, 6, 8, 22, 47), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (974, datetime.datetime(2005, 5, 30, 20, 28), 2617, 596, datetime.datetime(2005, 6, 8, 23, 45), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (975, datetime.datetime(2005, 5, 30, 21, 7), 3109, 7, datetime.datetime(2005, 6, 3, 1, 48), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (976, datetime.datetime(2005, 5, 30, 21, 11), 2290, 581, datetime.datetime(2005, 6, 6, 2, 16), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (977, datetime.datetime(2005, 5, 30, 21, 22), 2029, 394, datetime.datetime(2005, 6, 4, 22, 32), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (978, datetime.datetime(2005, 5, 30, 21, 30), 407, 154, datetime.datetime(2005, 6, 7, 16, 22), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (979, datetime.datetime(2005, 5, 30, 21, 37), 3917, 279, datetime.datetime(2005, 6, 8, 0, 24), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (980, datetime.datetime(2005, 5, 30, 21, 45), 4169, 273, datetime.datetime(2005, 6, 1, 20, 32), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (981, datetime.datetime(2005, 5, 30, 21, 52), 2913, 326, datetime.datetime(2005, 6, 1, 3, 15), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (982, datetime.datetime(2005, 5, 30, 22, 15), 3560, 524, datetime.datetime(2005, 6, 2, 16, 18), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (983, datetime.datetime(2005, 5, 30, 22, 15), 63, 115, datetime.datetime(2005, 6, 2, 22, 56), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (984, datetime.datetime(2005, 5, 30, 22, 17), 2305, 262, datetime.datetime(2005, 6, 1, 20, 15), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (985, datetime.datetime(2005, 5, 30, 22, 18), 1573, 564, datetime.datetime(2005, 6, 4, 23, 36), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (986, datetime.datetime(2005, 5, 30, 22, 22), 4045, 253, datetime.datetime(2005, 6, 1, 2, 24), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (987, datetime.datetime(2005, 5, 30, 22, 59), 390, 11, datetime.datetime(2005, 6, 7, 20, 56), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (988, datetime.datetime(2005, 5, 30, 23, 8), 1364, 12, datetime.datetime(2005, 6, 7, 0, 22), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (989, datetime.datetime(2005, 5, 30, 23, 11), 4388, 83, datetime.datetime(2005, 6, 3, 20, 36), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (990, datetime.datetime(2005, 5, 30, 23, 25), 4171, 311, datetime.datetime(2005, 6, 6, 18, 41), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (991, datetime.datetime(2005, 5, 30, 23, 29), 2863, 593, datetime.datetime(2005, 6, 7, 23, 16), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (992, datetime.datetime(2005, 5, 30, 23, 47), 3572, 123, datetime.datetime(2005, 6, 5, 19, 1), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (993, datetime.datetime(2005, 5, 30, 23, 54), 2080, 513, datetime.datetime(2005, 6, 4, 21, 27), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (994, datetime.datetime(2005, 5, 30, 23, 55), 2798, 472, datetime.datetime(2005, 6, 4, 1, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (995, datetime.datetime(2005, 5, 31, 0, 6), 17, 150, datetime.datetime(2005, 6, 6, 2, 30), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (996, datetime.datetime(2005, 5, 31, 0, 6), 2075, 331, datetime.datetime(2005, 5, 31, 21, 29), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (997, datetime.datetime(2005, 5, 31, 0, 8), 4243, 216, datetime.datetime(2005, 6, 2, 0, 17), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (998, datetime.datetime(2005, 5, 31, 0, 16), 3395, 389, datetime.datetime(2005, 6, 1, 22, 41), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (999, datetime.datetime(2005, 5, 31, 0, 25), 4433, 413, datetime.datetime(2005, 6, 3, 6, 5), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (1000, datetime.datetime(2005, 5, 31, 0, 25), 1774, 332, datetime.datetime(2005, 6, 8, 19, 42), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (1001, datetime.datetime(2005, 5, 31, 0, 46), 1498, 64, datetime.datetime(2005, 6, 6, 6, 14), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  ...]

# %%
# %%sql
# select count(*) from rental
# Out:
#  * postgresql://localhost/postgres
# 1 rows affected.
# [(16044,)]

# %%
# %%sql
# select count(distinct rental_id) from rental
# Out:
#  * postgresql://localhost/postgres
# 1 rows affected.
# [(16044,)]

# %%
# %%sql
# -- Investigating distinct values to determine what identifies a unique row
# select
#     count(distinct rental_id) as rental_id_count,
#     count(distinct rental_date) as rental_date_count,
#     count(distinct inventory_id) as inventory_id_count,
#     count(distinct customer_id) as customer_id_count,
#     count(distinct staff_id) as staff_id_count,
#     count(distinct last_update) as last_update_count
# from rental
# Out:
#  * sqlite://
# Done.
# [(16044, 13319, 4580, 599, 2, 3)]

# %%
# %%sql
# select * from rental where rental_date > return_date
# Out:
#  * postgresql://localhost/postgres
# 281 rows affected.
# [(11611, datetime.datetime(2006, 2, 14, 15, 16), 1857, 192, datetime.datetime(1900, 1, 1, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (11646, datetime.datetime(2006, 2, 14, 15, 16), 478, 11, datetime.datetime(1900, 1, 1, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (11652, datetime.datetime(2006, 2, 14, 15, 16), 1622, 597, datetime.datetime(1900, 1, 1, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (11657, datetime.datetime(2006, 2, 14, 15, 16), 3043, 53, datetime.datetime(1900, 1, 1, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (11672, datetime.datetime(2006, 2, 14, 15, 16), 3947, 521, datetime.datetime(1900, 1, 1, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (11676, datetime.datetime(2006, 2, 14, 15, 16), 4496, 216, datetime.datetime(1900, 1, 1, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (11709, datetime.datetime(2006, 2, 14, 15, 16), 1720, 330, datetime.datetime(1900, 1, 1, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (
 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (996, datetime.datetime(2005, 5, 31, 0, 6), 2075, 331, datetime.datetime(2005, 5, 31, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (1213, datetime.datetime(2005, 6, 15, 3, 14), 3191, 94, datetime.datetime(2005, 6, 15, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (1557, datetime.datetime(2005, 6, 16, 2, 28), 2617, 439, datetime.datetime(2005, 6, 16, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (1565, datetime.datetime(2005, 6, 16, 3, 13), 3833, 506, datetime.datetime(2005, 6, 16, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (1870, datetime.datetime(2005, 6, 17, 2, 24), 895, 191, datetime.datetime(2005, 6, 17, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (1904, datetime.datetime(2005, 6, 17, 4, 45), 2472, 87, datetime.datetime(2005, 6, 17, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (2218, datetime.datetime(2005, 6, 18, 3, 13), 3577, 176, datetime.datetime(2005, 6, 18, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (2224, datetime.datetime(2005, 6, 18, 3, 33), 1336, 153, datetime.datetime(2005, 6, 18, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (2214, datetime.datetime(2005, 6, 18, 2, 44), 2430, 366, datetime.datetime(2005, 6, 18, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (2539, datetime.datetime(2005, 6, 19, 1, 58), 4474, 527, datetime.datetime(2005, 6, 19, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (2567, datetime.datetime(2005, 6, 19, 4, 4), 216, 496, datetime.datetime(2005, 6, 19, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (2866, datetime.datetime(2005, 6, 20, 0, 1), 2718, 44, datetime.datetime(2005, 6, 20, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (2907, datetime.datetime(2005, 6, 20, 3, 15), 2516, 208, datetime.datetime(2005, 6, 20, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (3205, datetime.datetime(2005, 6, 21, 0, 38), 2964, 31, datetime.datetime(2005, 6, 21, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (3195, datetime.datetime(2005, 6, 21, 0, 2), 2383, 165, datetime.datetime(2005, 6, 21, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (3549, datetime.datetime(2005, 7, 6, 2, 24), 3921, 19, datetime.datetime(2005, 7, 6, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (3556, datetime.datetime(2005, 7, 6, 2, 46), 3142, 273, datetime.datetime(2005, 7, 6, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (3528, datetime.datetime(2005, 7, 6, 1, 13), 1954, 201, datetime.datetime(2005, 7, 6, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (4036, datetime.datetime(2005, 7, 7, 2, 48), 500, 397, datetime.datetime(2005, 7, 7, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (4496, datetime.datetime(2005, 7, 8, 1, 44), 150, 578, datetime.datetime(2005, 7, 8, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (4464, datetime.datetime(2005, 7, 8, 0, 7), 4484, 583, datetime.datetime(2005, 7, 8, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (4520, datetime.datetime(2005, 7, 8, 2, 53), 3505, 104, datetime.datetime(2005, 7, 8, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (4476, datetime.datetime(2005, 7, 8, 0, 34), 395, 279, datetime.datetime(2005, 7, 8, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (4574, datetime.datetime(2005, 7, 8, 5, 39), 536, 257, datetime.datetime(2005, 7, 8, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (4986, datetime.datetime(2005, 7, 9, 0, 44), 3517, 589, datetime.datetime(2005, 7, 9, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (5004, datetime.datetime(2005, 7, 9, 1, 20), 2637, 382, datetime.datetime(2005, 7, 9, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (4994, datetime.datetime(2005, 7, 9, 0, 54), 2546, 246, datetime.datetime(2005, 7, 9, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (5016, datetime.datetime(2005, 7, 9, 1, 57), 1871, 5, datetime.datetime(2005, 7, 9, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (5070, datetime.datetime(2005, 7, 9, 4, 58), 2305, 407, datetime.datetime(2005, 7, 9, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (5071, datetime.datetime(2005, 7, 9, 5, 0), 4358, 12, datetime.datetime(2005, 7, 9, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (5053, datetime.datetime(2005, 7, 9, 3, 59), 570, 295, datetime.datetime(2005, 7, 9, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (5020, datetime.datetime(2005, 7, 9, 2, 7), 4113, 565, datetime.datetime(2005, 7, 9, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (5487, datetime.datetime(2005, 7, 10, 0, 1), 1144, 341, datetime.datetime(2005, 7, 10, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (5589, datetime.datetime(2005, 7, 10, 4, 22), 3673, 296, datetime.datetime(2005, 7, 10, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (5608, datetime.datetime(2005, 7, 10, 5, 8), 3854, 384, datetime.datetime(2005, 7, 10, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (6051, datetime.datetime(2005, 7, 11, 3, 46), 2675, 435, datetime.datetime(2005, 7, 11, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (6001, datetime.datetime(2005, 7, 11, 1, 24), 1779, 45, datetime.datetime(2005, 7, 11, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (6061, datetime.datetime(2005, 7, 11, 4, 6), 1859, 392, datetime.datetime(2005, 7, 11, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (6025, datetime.datetime(2005, 7, 11, 2, 18), 3306, 113, datetime.datetime(2005, 7, 11, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (6476, datetime.datetime(2005, 7, 12, 1, 37), 978, 28, datetime.datetime(2005, 7, 12, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (6483, datetime.datetime(2005, 7, 12, 1, 59), 1053, 263, datetime.datetime(2005, 7, 12, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (6437, datetime.datetime(2005, 7, 12, 0, 20), 4539, 355, datetime.datetime(2005, 7, 12, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (6959, datetime.datetime(2005, 7, 27, 0, 7), 1618, 452, datetime.datetime(2005, 7, 27, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (7608, datetime.datetime(2005, 7, 28, 0, 8), 1256, 167, datetime.datetime(2005, 7, 28, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (7611, datetime.datetime(2005, 7, 28, 0, 11), 3347, 467, datetime.datetime(2005, 7, 28, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (7638, datetime.datetime(2005, 7, 28, 1, 13), 1890, 172, datetime.datetime(2005, 7, 28, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (7649, datetime.datetime(2005, 7, 28, 1, 37), 2704, 318, datetime.datetime(2005, 7, 28, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (7653, datetime.datetime(2005, 7, 28, 1, 58), 814, 232, datetime.datetime(2005, 7, 28, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (8239, datetime.datetime(2005, 7, 29, 0, 31), 3951, 549, datetime.datetime(2005, 7, 29, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (8270, datetime.datetime(2005, 7, 29, 1, 27), 3565, 282, datetime.datetime(2005, 7, 29, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (8315, datetime.datetime(2005, 7, 29, 3, 37), 1420, 135, datetime.datetime(2005, 7, 29, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (8925, datetime.datetime(2005, 7, 30, 2, 9), 3753, 500, datetime.datetime(2005, 7, 30, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (8903, datetime.datetime(2005, 7, 30, 1, 8), 4546, 406, datetime.datetime(2005, 7, 30, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (9628, datetime.datetime(2005, 7, 31, 4, 51), 1387, 565, datetime.datetime(2005, 7, 31, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (10214, datetime.datetime(2005, 8, 1, 1, 4), 648, 597, datetime.datetime(2005, 8, 1, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (10190, datetime.datetime(2005, 8, 1, 0, 27), 4411, 138, datetime.datetime(2005, 8, 1, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (10261, datetime.datetime(2005, 8, 1, 2, 58), 2346, 50, datetime.datetime(2005, 8, 1, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (10302, datetime.datetime(2005, 8, 1, 4, 12), 1043, 144, datetime.datetime(2005, 8, 1, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (10328, datetime.datetime(2005, 8, 1, 4, 56), 1191, 85, datetime.datetime(2005, 8, 1, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (10292, datetime.datetime(2005, 8, 1, 3, 42), 2562, 340, datetime.datetime(2005, 8, 1, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (10236, datetime.datetime(2005, 8, 1, 2, 5), 3754, 470, datetime.datetime(2005, 8, 1, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (10296, datetime.datetime(2005, 8, 1, 4, 4), 1958, 573, datetime.datetime(2005, 8, 1, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (10907, datetime.datetime(2005, 8, 2, 1, 51), 1430, 561, datetime.datetime(2005, 8, 2, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (10870, datetime.datetime(2005, 8, 2, 0, 27), 1509, 33, datetime.datetime(2005, 8, 2, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (10918, datetime.datetime(2005, 8, 2, 2, 10), 3418, 2, datetime.datetime(2005, 8, 2, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (10854, datetime.datetime(2005, 8, 2, 0, 2), 3295, 356, datetime.datetime(2005, 8, 2, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (10963, datetime.datetime(2005, 8, 2, 3, 48), 4501, 36, datetime.datetime(2005, 8, 2, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (11571, datetime.datetime(2005, 8, 17, 1, 37), 203, 296, datetime.datetime(2005, 8, 17, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (11620, datetime.datetime(2005, 8, 17, 4, 6), 3801, 502, datetime.datetime(2005, 8, 17, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (12155, datetime.datetime(2005, 8, 18, 0, 24), 2065, 315, datetime.datetime(2005, 8, 18, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (12168, datetime.datetime(2005, 8, 18, 1, 3), 2859, 535, datetime.datetime(2005, 8, 18, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (12200, datetime.datetime(2005, 8, 18, 2, 12), 840, 52, datetime.datetime(2005, 8, 18, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (12188, datetime.datetime(2005, 8, 18, 1, 51), 2989, 456, datetime.datetime(2005, 8, 18, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (12259, datetime.datetime(2005, 8, 18, 4, 14), 2904, 429, datetime.datetime(2005, 8, 18, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (12286, datetime.datetime(2005, 8, 18, 4, 57), 3729, 34, datetime.datetime(2005, 8, 18, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (12151, datetime.datetime(2005, 8, 18, 0, 14), 1976, 4, datetime.datetime(2005, 8, 18, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (12855, datetime.datetime(2005, 8, 19, 2, 18), 2900, 242, datetime.datetime(2005, 8, 19, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (12813, datetime.datetime(2005, 8, 19, 0, 54), 3285, 500, datetime.datetime(2005, 8, 19, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (12796, datetime.datetime(2005, 8, 19, 0, 22), 1285, 368, datetime.datetime(2005, 8, 19, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (12890, datetime.datetime(2005, 8, 19, 3, 42), 3831, 150, datetime.datetime(2005, 8, 19, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (12852, datetime.datetime(2005, 8, 19, 2, 12), 2446, 260, datetime.datetime(2005, 8, 19, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (13467, datetime.datetime(2005, 8, 20, 0, 56), 696, 373, datetime.datetime(2005, 8, 20, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (13475, datetime.datetime(2005, 8, 20, 1, 5), 3214, 68, datetime.datetime(2005, 8, 20, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (14108, datetime.datetime(2005, 8, 21, 0, 52), 4339, 243, datetime.datetime(2005, 8, 21, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (14163, datetime.datetime(2005, 8, 21, 2, 56), 1007, 204, datetime.datetime(2005, 8, 21, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (14128, datetime.datetime(2005, 8, 21, 1, 35), 2594, 81, datetime.datetime(2005, 8, 21, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (14104, datetime.datetime(2005, 8, 21, 0, 37), 912, 178, datetime.datetime(2005, 8, 21, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (14823, datetime.datetime(2005, 8, 22, 1, 24), 680, 503, datetime.datetime(2005, 8, 22, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (14780, datetime.datetime(2005, 8, 22, 0, 6), 3171, 491, datetime.datetime(2005, 8, 22, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (14864, datetime.datetime(2005, 8, 22, 2, 57), 2872, 460, datetime.datetime(2005, 8, 22, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (14836, datetime.datetime(2005, 8, 22, 1, 52), 4287, 418, datetime.datetime(2005, 8, 22, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (14803, datetime.datetime(2005, 8, 22, 0, 49), 2525, 278, datetime.datetime(2005, 8, 22, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (15429, datetime.datetime(2005, 8, 23, 0, 20), 740, 241, datetime.datetime(2005, 8, 23, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (15491, datetime.datetime(2005, 8, 23, 2, 8), 2059, 28, datetime.datetime(2005, 8, 23, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (15499, datetime.datetime(2005, 8, 23, 2, 37), 630, 488, datetime.datetime(2005, 8, 23, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (15474, datetime.datetime(2005, 8, 23, 1, 39), 3015, 188, datetime.datetime(2005, 8, 23, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30)),
#  (15498, datetime.datetime(2005, 8, 23, 2, 33), 1583, 83, datetime.datetime(2005, 8, 23, 0, 0), 1, datetime.datetime(2006, 2, 16, 2, 30)),
#  (15475, datetime.datetime(2005, 8, 23, 1, 44), 4503, 562, datetime.datetime(2005, 8, 23, 0, 0), 2, datetime.datetime(2006, 2, 16, 2, 30))]

# %%
# %%sql
# select
#   column_name,
#   data_type,
#   character_maximum_length
# from
#   information_schema.columns
# where
#   table_name = 'rental';
# Out:
#  * postgresql://localhost/postgres
# 7 rows affected.
# [('rental_id', 'integer', None),
#  ('rental_date', 'timestamp without time zone', None),
#  ('inventory_id', 'integer', None),
#  ('customer_id', 'integer', None),
#  ('return_date', 'timestamp without time zone', None),
#  ('staff_id', 'integer', None),
#  ('last_update', 'timestamp without time zone', None)]

# %%
# %%sql
# select count(distinct rental_id) from rental
# Out:
#  * postgresql://localhost/postgres
# 1 rows affected.
# [(16044,)]

# %%
# %%sql
# -- Number of rentals per customer
# select customer_id, count(*) as count
# from rental
# group by customer_id
# order by count desc
# Out:
#  * postgresql://localhost/postgres
# 599 rows affected.
# [(148, 46),
#  (526, 45),
#  (236, 42),
#  (144, 42),
#  (75, 41),
#  (197, 40),
#  (469, 40),
#  (137, 39),
#  (468, 39),
#  (178, 39),
#  (459, 38),
#  (295, 38),
#  (5, 38),
#  (410, 38),
#  (366, 37),
#  (257, 37),
#  (198, 37),
#  (176, 37),
#  (267, 36),
#  (380, 36),
#  (29, 36),
#  (354, 36),
#  (348, 36),
#  (439, 36),
#  (403, 35),
#  (381, 35),
#  (196, 35),
#  (50, 35),
#  (204, 35),
#  (373, 35),
#  (274, 35),
#  (21, 35),
#  (91, 35),
#  (273, 35),
#  (506, 35),
#  (371, 35),
#  (368, 35),
#  (26, 34),
#  (38, 34),
#  (119, 34),
#  (566, 34),
#  (211, 34),
#  (372, 34),
#  (239, 34),
#  (46, 34),
#  (576, 34),
#  (30, 34),
#  (502, 34),
#  (207, 34),
#  (360, 34),
#  (181, 34),
#  (473, 34),
#  (241, 34),
#  (129, 34),
#  (138, 34),
#  (168, 34),
#  (66, 34),
#  (147, 34),
#  (237, 33),
#  (533, 33),
#  (7, 33),
#  (84, 33),
#  (102, 33),
#  (454, 33),
#  (51, 33),
#  (438, 33),
#  (230, 33),
#  (314, 33),
#  (297, 33),
#  (390, 33),
#  (172, 33),
#  (462, 33),
#  (451, 33),
#  (70, 18),
#  (194, 18),
#  (124, 18),
#  (315, 17),
#  (48, 17),
#  (465, 17),
#  (223, 17),
#  (555, 17),
#  (464, 16),
#  (492, 16),
#  (398, 16),
#  (164, 16),
#  (136, 15),
#  (248, 15),
#  (110, 14),
#  (281, 14),
#  (61, 14),
#  (318, 12)]

# %% [markdown]
# ### FILM
# * All of the films available from the dvd rental store <br>
# * Useful for playing with arrays and strings <br>
# * Wildcard matching also a good topic for this data set

# %%
# %%sql
# select sum(case when upper(description) like '%MOOSE%' then 1 else 0 end) as moose_count, count(*) from film
# Out:
#  * postgresql://localhost/postgres
# 1 rows affected.
# [(80, 1000)]

# %%
# %%sql
# select count(distinct film_id) from film
# Out:
#  * postgresql://localhost/postgres
# 1 rows affected.
# [(1000,)]

# %%
# %%sql
# select special_features[1] from films
# Out:
#  * postgresql://localhost/postgres
# 1000 rows affected.
# [('Trailers',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Deleted Scenes',),
#  ('Deleted Scenes',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Deleted Scenes',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Behind the Scenes',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Behind the Scenes',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Deleted Scenes',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Behind the Scenes',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Behind the Scenes',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Deleted Scenes',),
#  ('Deleted Scenes',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Behind the Scenes',),
#  ('Behind the Scenes',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Behind the Scenes',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Behind the Scenes',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Behind the Scenes',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Behind the Scenes',),
#  ('Behind the Scenes',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Behind the Scenes',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Deleted Scenes',),
#  ('Behind the Scenes',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Behind the Scenes',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Behind the Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Behind the Scenes',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Behind the Scenes',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Deleted Scenes',),
#  ('Deleted Scenes',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Behind the Scenes',),
#  ('Deleted Scenes',),
#  ('Behind the Scenes',),
#  ('Commentaries',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Commentaries',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Trailers',),
#  ('Deleted Scenes',),
#  ('Trailers',),
#  ('Trailers',)]

# %%
# %%sql
# select distinct special_features from film
# Out:
#  * postgresql://localhost/postgres
# 15 rows affected.
# [(['Commentaries', 'Deleted Scenes', 'Behind the Scenes'],),
#  (['Trailers', 'Deleted Scenes'],),
#  (['Trailers'],),
#  (['Trailers', 'Commentaries', 'Deleted Scenes'],),
#  (['Trailers', 'Commentaries', 'Behind the Scenes'],),
#  (['Commentaries'],),
#  (['Commentaries', 'Behind the Scenes'],),
#  (['Trailers', 'Commentaries'],),
#  (['Deleted Scenes', 'Behind the Scenes'],),
#  (['Commentaries', 'Deleted Scenes'],),
#  (['Deleted Scenes'],),
#  (['Behind the Scenes'],),
#  (['Trailers', 'Deleted Scenes', 'Behind the Scenes'],),
#  (['Trailers', 'Commentaries', 'Deleted Scenes', 'Behind the Scenes'],),
#  (['Trailers', 'Behind the Scenes'],)]

# %%
# %%sql
# select
#   special_features,
#   count(distinct film_id) as count
# from
#   (select film_id, unnest(special_features) as special_features from film) expand
# group by
#   special_features
# order by
#   count desc
# Out:
#  * postgresql://localhost/postgres
# 4 rows affected.
# [('Commentaries', 539),
#  ('Behind the Scenes', 538),
#  ('Trailers', 535),
#  ('Deleted Scenes', 503)]

# %%
# %%sql
# select rating, count(distinct film_id) from film group by rating
# Out:
#  * postgresql://localhost/postgres
# 5 rows affected.
# [('G', 178), ('NC-17', 210), ('PG', 194), ('PG-13', 223), ('R', 195)]

# %%
# %%sql
# select rental_rate, count(distinct film_id) from film group by rental_rate
# Out:
#  * postgresql://localhost/postgres
# 3 rows affected.
# [(0.99, 341), (2.99, 323), (4.99, 336)]

# %% [markdown]
# ### LANGUAGE
# * Metadata table that lists all the langauges of the films <br>
# * Joins onto the films data set <br>
# * This table shouldn't have any mistakes - the join might need to be looked at

# %%
# %%sql
# select * from language
# Out:
#  * postgresql://localhost/postgres
# 6 rows affected.
# [(1, 'English             ', datetime.datetime(2006, 2, 15, 10, 2)),
#  (2, 'Italian             ', datetime.datetime(2006, 2, 15, 10, 2)),
#  (3, 'Japanese            ', datetime.datetime(2006, 2, 15, 10, 2)),
#  (4, 'Mandarin            ', datetime.datetime(2006, 2, 15, 10, 2)),
#  (5, 'French              ', datetime.datetime(2006, 2, 15, 10, 2)),
#  (6, 'German              ', datetime.datetime(2006, 2, 15, 10, 2))]

# %%
# %%sql
# -- Why aren't there films in other langauges
# select
#   name as film_language,
#   count(distinct film_id)
# from
#   films
# left join
#   language
# on films.language_id = language.language_id
# group by
#   name
# Out:
#  * postgresql://localhost/postgres
# 1 rows affected.
# [('English             ', 1000)]

# %% [markdown]
# ### FILM_CATEGORY
# * Denotes what category each film belongs in
# * Each film only has one film category (which is not always necessarily true in the real world)
# * Checks for legit categories that appear in other data sets

# %%
# %%sql
# select
#   cast(film_id as int) as film_id,
#   cast(category_id as int) as category_id
# from
#   film_category
# group by
#   film_id,
#   category_id
# having
#   count(*) > 1
# Out:
#  * postgresql://localhost/postgres
# 0 rows affected.
# []

# %%
# %%sql
# select
#   column_name,
#   data_type
# from
#   information_schema.columns
# where
#   table_name = 'film_category';
# Out:
#  * postgresql://localhost/postgres
# 3 rows affected.
# [('film_id', 'double precision'),
#  ('category_id', 'double precision'),
#  ('last_update', 'timestamp without time zone')]

# %%
# %%sql
# select * from film_category where cast(film_id as int) not in (select distinct film_id from films)
# Out:
#  * postgresql://localhost/postgres
# 0 rows affected.
# []

# %%
# %%sql
# select * from film_category where cast(category_id as int) not in (select distinct category_id from category)
# Out:
#  * postgresql://localhost/postgres
# 0 rows affected.
# []

# %% [markdown]
# ### CATEGORY
# * Straightforward data set
# * No data cleaning required
# * last_update can be the same time

# %%
# %%sql
# select * from category
# Out:
#  * postgresql://localhost/postgres
# 16 rows affected.
# [(1, 'Action', datetime.datetime(2006, 2, 15, 9, 46)),
#  (2, 'Animation', datetime.datetime(2006, 2, 15, 9, 46)),
#  (3, 'Children', datetime.datetime(2006, 2, 15, 9, 46)),
#  (4, 'Classics', datetime.datetime(2006, 2, 15, 9, 46)),
#  (5, 'Comedy', datetime.datetime(2006, 2, 15, 9, 46)),
#  (6, 'Documentary', datetime.datetime(2006, 2, 15, 9, 46)),
#  (7, 'Drama', datetime.datetime(2006, 2, 15, 9, 46)),
#  (8, 'Family', datetime.datetime(2006, 2, 15, 9, 46)),
#  (9, 'Foreign', datetime.datetime(2006, 2, 15, 9, 46)),
#  (10, 'Games', datetime.datetime(2006, 2, 15, 9, 46)),
#  (11, 'Horror', datetime.datetime(2006, 2, 15, 9, 46)),
#  (12, 'Music', datetime.datetime(2006, 2, 15, 9, 46)),
#  (13, 'New', datetime.datetime(2006, 2, 15, 9, 46)),
#  (14, 'Sci-Fi', datetime.datetime(2006, 2, 15, 9, 46)),
#  (15, 'Sports', datetime.datetime(2006, 2, 15, 9, 46)),
#  (16, 'Travel', datetime.datetime(2006, 2, 15, 9, 46))]

# %%
# %%sql
# select * from category where category_id not in (select distinct cast(category_id as int) from film_category)
# Out:
#  * postgresql://localhost/postgres
# 0 rows affected.
# []
